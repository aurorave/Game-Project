# %%
import pandas as pd
import numpy as np

url = 'https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/datasets/vgames2.csv'
df = pd.read_csv(url)
df = df.iloc[:,1:]
df.head(4) # df.shape: (16598, 9)
# Out:
#                                              Name Platform    Year      Genre  \
# 0                    Candace Kane's Candy Factory       DS  2008.0     Action
# 1                                  The Munchables      Wii  2009.0     Action
# 2  Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010.0  Adventure
# 3                Deal or No Deal: Special Edition       DS  2010.0       Misc
#
#             Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 0           Destineer     0.04        0        0           0
# 1  Namco Bandai Games     0.17        0        0        0.01
# 2           Alchemist        0        0     0.02           0
# 3           Zoo Games     0.04        0        0           0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         16598 non-null  object
#  1   Platform     16598 non-null  object
#  2   Year         16327 non-null  float64
#  3   Genre        16548 non-null  object
#  4   Publisher    16540 non-null  object
#  5   NA_Sales     16598 non-null  object
#  6   EU_Sales     16598 non-null  object
#  7   JP_Sales     16598 non-null  object
#  8   Other_Sales  16598 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 1.1+ MB

# %%
df.nunique()
# Out:
# Name           11493
# Platform          31
# Year              62
# Genre             12
# Publisher        578
# NA_Sales         494
# EU_Sales         363
# JP_Sales         282
# Other_Sales      190
# dtype: int64

# %%
df.isna().sum()
# Out:
# Name             0
# Platform         0
# Year           271
# Genre           50
# Publisher       58
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# dtype: int64

# %%
df[df.Year.isnull()]
# Out:
#                                               Name Platform  Year       Genre  \
# 31                                       Rock Band     X360   NaN        Misc
# 109     Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)      Wii   NaN      Racing
# 273    Jewel Link Chronicles: Mountains of Madness       DS   NaN      Puzzle
# 358             Majesty 2: The Fantasy Kingdom Sim     X360   NaN  Simulation
# 430                                     Famista 64      N64   NaN      Sports
# ...                                            ...      ...   ...         ...
# 16240                                Freaky Flyers       GC   NaN      Racing
# 16275                               Space Invaders     2600   NaN     Shooter
# 16278                                Madden NFL 11      Wii   NaN      Sports
# 16425                               Yoostar on MTV     X360   NaN        Misc
# 16432                                  Bejeweled 3     X360   NaN      Puzzle
#
#                 Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 31        Electronic Arts     1.93     0.34        0        0.21
# 109               Unknown        0        0     0.02           0
# 273             Avanquest        0     0.06        0        0.01
# 358               Unknown     0.03        0        0           0
# 430    Namco Bandai Games        0        0     0.17        0.03
# ...                   ...      ...      ...      ...         ...
# 16240             Unknown     0.01        0        0           0
# 16275               Atari     2.36     0.14       0M        0.03
# 16278             Unknown      0.7        0        0         50K
# 16425             Unknown     0.06        0        0           0
# 16432             Unknown     0.13        0        0        0.01
#
# [271 rows x 9 columns]

# %%
# Year 데이터 이상치 확인 및 yr_tbc (year to be changed)로 담아두기
year = df.Year.unique()
yr_tbc = []
for i in year:
    if i <= 1900:
        print(i)
        yr_tbc.append(i)
# Out:
# 9.0
# 97.0
# 11.0
# 15.0
# 3.0
# 96.0
# 6.0
# 8.0
# 1.0
# 5.0
# 4.0
# 10.0
# 98.0
# 7.0
# 16.0
# 86.0
# 14.0
# 95.0
# 2.0
# 13.0
# 0.0
# 12.0
# 94.0

# %%
df[(df.Year >= 0.0) & (df.Year < 1900.0)].sort_values(by = 'Year', ascending = False)
# 확인 결과 Year > 80: 2000년대 출시, Year < 80: 1900년대 출시
# Out:
#                                    Name Platform  Year     Genre  \
# 16482  Super Robot Taisen F Kanketsuhen      SAT  98.0  Strategy
# 14572                         S.C.A.R.S       PS  98.0    Racing
# 3492                             Glover      N64  98.0  Platform
# 10315              AeroFighters Assault      N64  97.0    Action
# 81                Treasures of the Deep       PS  97.0    Action
# ...                                 ...      ...   ...       ...
# 8681                 NCAA Football 2002      PS2   1.0    Sports
# 2249                         SplashDown      PS2   1.0    Racing
# 14666                         Strider 2       PS   0.0  Platform
# 9276          Trade & Battle: Card Hero       GB   0.0  Strategy
# 16394                     Point Blank 3       PS   0.0   Shooter
#
#                 Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 16482           Banpresto       0M        0     0.55           0
# 14572             Ubisoft     0.05     0.03        0        0.01
# 3492   Hasbro Interactive     0.72     0.17        0        0.01
# 10315        Video System     0.15     0.04        0           0
# 81     Namco Bandai Games      0.1     0.07        0        0.01
# ...                   ...      ...      ...      ...         ...
# 8681      Electronic Arts     0.77      0.6        0         0.2
# 2249                Atari     0.34     0.27        0        0.09
# 14666  Virgin Interactive     0.05     0.03        0        0.01
# 9276             Nintendo        0        0      0.2           0
# 16394  Namco Bandai Games     0.01     0.01        0           0
#
# [100 rows x 9 columns]

# %%
# 위의 확인결과에 따라 Year 데이터 변경 (80 전후로 각각 1900, 2000씩 더해주도록 한다.)
df.loc[(df.Year.values < 80), 'Year'] += 2000 # c += a → c = (c + a)
df.loc[((df.Year.values > 80) & (df.Year.values < 100)), 'Year'] += 1900
df.Year.value_counts() # Year 데이터가 1980년대부터 2020년에 이르기까지 정상 변경 확인가능
# Out:
# 2009.0    1431
# 2008.0    1428
# 2010.0    1259
# 2007.0    1202
# 2011.0    1139
# 2006.0    1008
# 2005.0     941
# 2002.0     829
# 2003.0     775
# 2004.0     763
# 2012.0     657
# 2015.0     614
# 2014.0     582
# 2013.0     546
# 2001.0     482
# 1998.0     379
# 2000.0     349
# 2016.0     344
# 1999.0     338
# 1997.0     289
# 1996.0     263
# 1995.0     219
# 1994.0     121
# 1993.0      60
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      36
# 1986.0      21
# 1989.0      17
# 1983.0      17
# 1990.0      16
# 1987.0      16
# 1988.0      15
# 1984.0      14
# 1985.0      14
# 1980.0       9
# 2017.0       3
# 2020.0       1
# Name: Year, dtype: int64

# %%
# Year 데이터가 결측치인 게임의 Name, Platform 확인
# 각각 names_list, platforms_list 로 모아줌
names_list = []
platform_list = []

for x, y in zip(df.loc[(df.Year.isna()), 'Name'], df.loc[(df.Year.isna()), 'Platform']):
    names_list.append(x)
    platform_list.append(y)

print(names_list[-3:]) # [-3:]: 맨끝 3개 데이터 출력
print(platform_list[-3:])    

# 출력
# ['Madden NFL 11', 'Yoostar on MTV', 'Bejeweled 3']
# ['Wii', 'X360', 'X360']

# df.loc[(df.Year.isna()), 'Name']: Year 데이터가 이상치인 게임의 Name 출력
# Out:
# ['Madden NFL 11', 'Yoostar on MTV', 'Bejeweled 3']
# ['Wii', 'X360', 'X360']

# %%
yr_nan_df = pd.DataFrame({'Name': names_list, 'Platform': platform_list, 'Year': 0})
yr_nan_df.head() # yr_nan_df.shape: (271, 3)
# Out:
#                                           Name Platform  Year
# 0                                    Rock Band     X360     0
# 1   Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)      Wii     0
# 2  Jewel Link Chronicles: Mountains of Madness       DS     0
# 3           Majesty 2: The Fantasy Kingdom Sim     X360     0
# 4                                   Famista 64      N64     0

# %%
# Year 결측치 수집 - 데이터 크롤링 with selenium

! pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (4.2.0)
# Requirement already satisfied: trio~=0.17 in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from selenium) (0.21.0)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: async-generator>=1.9 in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: outcome in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: sniffio in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: idna in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (37.0.3)
# Requirement already satisfied: certifi in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (2022.6.15)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (22.0.0)
# Requirement already satisfied: pycparser in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)

# %%
! pip install webdriver-manager
# Out:
# Requirement already satisfied: webdriver-manager in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (3.7.0)
# Requirement already satisfied: python-dotenv in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from webdriver-manager) (0.20.0)
# Requirement already satisfied: requests in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from webdriver-manager) (2.28.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from requests->webdriver-manager) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from requests->webdriver-manager) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from requests->webdriver-manager) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\maeve\appdata\local\programs\python\python310\lib\site-packages (from requests->webdriver-manager) (3.3)

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import time
from bs4 import BeautifulSoup
# from urllib.parse import quote_plus

# %%
driver = webdriver.Chrome(ChromeDriverManager().install()) # driver = webdriver.Chrome('[크롬드라이버를 설치한 절대경로를 여기에 써주자.]')

# baseUrl = 'https://www.google.com/search?q=' #구글 검색의 기본 url : 검색 여러번하고 주소창 보면 공통 형식이 보인다.
# plusUrl = input(yr_nan_df['Name']) 
# url = baseUrl + quote_plus(plusUrl) #quote_plus : 문자열을 인터넷 검색가능한 형식으로 바꿔준다.

# platform name release date로 검색
for name, platform in zip(names_list, platform_list):
    driver.get('https://www.google.com/search?q={}'.format(platform + ' ' + name + ' ' +  "release date"))
    time.sleep(3)
        
    try: # xxxx년 xx월 xx일 데이터 수집
        html = driver.page_source # 브라우저에 보이는 그대로의 HTML, 크롬 개발자 도구의 Element 탭 내용과 동일.
        soup = BeautifulSoup(html, 'html.parser')
        date = soup.select('div.Z0LcW')
        year = date[0].text.split(" ")[0].replace("년", '').strip()
        yr_nan_df.loc[yr_nan_df.Name.values == name, 'Year'] = int(year)
    except:
        try: # x월 x일 x년 데이터 수집
            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            date = soup.select('div.Z0LcW')
            year =date[0].text.split(" ")[-1].strip()
            yr_nan_df.loc[yr_nan_df.Name.values == name, 'Year'] = int(year)
        except: # 못담을 경우 0으로 처리
            yr_nan_df.loc[yr_nan_df.Name.values == name, 'Year'] = 0
        
driver.quit()
yr_nan_df.to_csv('yr_nan_df.csv', index=False) # 수집후 저장

# 확인 결과 일부 Year 0으로 수집된 데이터에 대해 크롤링, 수작업 진행
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - About to download new driver from https://chromedriver.storage.googleapis.com/103.0.5060.53/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\maeve\.wdm\drivers\chromedriver\win32\103.0.5060.53]
# C:\Users\maeve\AppData\Local\Temp\ipykernel_12864\444249469.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install()) # driver = webdriver.Chrome('[크롬드라이버를 설치한 절대경로를 여기에 써주자.]')

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())

for x, y in zip(yr_nan_df.loc[(yr_nan_df.Year == 0), "Name"],
                yr_nan_df.loc[(yr_nan_df.Year == 0), "Platform"]):
    # platform name release date로 검색
    driver.get('https://www.google.com/search?q={}'.format(y+ ' ' + x + ' ' +  "release date"))
    # 검색해서 띄우고 입력받기
    year = int(input('year : '))
    # 입력받은 데이터 저장
    yr_nan_df.loc[yr_nan_df.Name == x, 'Year'] = year
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [C:\Users\maeve\.wdm\drivers\chromedriver\win32\103.0.5060.53\chromedriver.exe] found in cache
# C:\Users\maeve\AppData\Local\Temp\ipykernel_12864\3330395579.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
# 크롤링한 데이터 결측치 위치에 대체
for x, y, z in zip((yr_nan_df.Name.values),
                   (yr_nan_df.Platform.values),
                   (yr_nan_df.Year.values)):
        df.loc[((df.Name == x) & (df.Platform == y)), 'Year'] = z

# %%
df.Year.isna().sum()
# Out:
# 0

# %%
df.Year.value_counts().sort_values(ascending = False)
# Out:
# 2008.0    1451
# 2009.0    1451
# 2010.0    1279
# 2007.0    1220
# 2011.0    1179
# 2006.0    1029
# 2005.0     956
# 2002.0     854
# 2003.0     788
# 2004.0     775
# 2012.0     666
# 2015.0     615
# 2014.0     584
# 2013.0     550
# 2001.0     490
# 1998.0     381
# 2000.0     353
# 2016.0     345
# 1999.0     341
# 1997.0     292
# 1996.0     264
# 1995.0     219
# 1994.0     121
# 1993.0      61
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      37
# 1986.0      21
# 1989.0      18
# 1983.0      17
# 1987.0      16
# 1990.0      16
# 1988.0      15
# 1984.0      14
# 1980.0      14
# 1985.0      14
# 1978.0       5
# 1977.0       4
# 2021.0       3
# 2017.0       3
# 2019.0       2
# 2020.0       2
# 2018.0       2
# 4.0          1
# Name: Year, dtype: int64

# %%
df.loc[(df.Year.values < 80), 'Year'] += 2000 # c += a → c = (c + a)
df.loc[((df.Year.values > 80) & (df.Year.values < 100)), 'Year'] += 1900
df.Year.value_counts()
# Out:
# 2008.0    1451
# 2009.0    1451
# 2010.0    1279
# 2007.0    1220
# 2011.0    1179
# 2006.0    1029
# 2005.0     956
# 2002.0     854
# 2003.0     788
# 2004.0     776
# 2012.0     666
# 2015.0     615
# 2014.0     584
# 2013.0     550
# 2001.0     490
# 1998.0     381
# 2000.0     353
# 2016.0     345
# 1999.0     341
# 1997.0     292
# 1996.0     264
# 1995.0     219
# 1994.0     121
# 1993.0      61
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      37
# 1986.0      21
# 1989.0      18
# 1983.0      17
# 1987.0      16
# 1990.0      16
# 1988.0      15
# 1980.0      14
# 1985.0      14
# 1984.0      14
# 1978.0       5
# 1977.0       4
# 2021.0       3
# 2017.0       3
# 2019.0       2
# 2020.0       2
# 2018.0       2
# Name: Year, dtype: int64

# %%
df.Year.unique()
# Out:
# array([2008, 2009, 2010, 2005, 2011, 2007, 2001, 2003, 2006, 2014, 2015,
#        2002, 1997, 2013, 1996, 2004, 2000, 1984, 1998, 2016, 1985, 1999,
#        1995, 1993, 2012, 1987, 1982, 1994, 1990, 1992, 1991, 1983, 1988,
#        1981, 1989, 1986, 1980, 2021, 1978, 2017, 2019, 2020, 1977, 2018],
#       dtype=int64)

# %%
# 1-4. Genre 결측치 수집
# 1-4-1. Genre 결측치 확인

df.Genre.unique()
# Out:
# array(['Action', 'Adventure', 'Misc', 'Platform', 'Sports', 'Simulation',
#        'Racing', 'Role-Playing', 'Puzzle', 'Strategy', 'Fighting',
#        'Shooter', nan], dtype=object)

# %%
df.loc[df.Genre.isna()]
# Out:
#                                               Name Platform    Year Genre  \
# 50                        Ape Escape: On the Loose      PSP  2005.0   NaN
# 408                                    NBA Ballers       XB  2004.0   NaN
# 1328                                    NFL Street       XB  2004.0   NaN
# 1582                SingStar Singalong With Disney      PS2  2008.0   NaN
# 1971                           Pokemon X/Pokemon Y      3DS  2013.0   NaN
# 2043                                 NASCAR Racing       PS  1996.0   NaN
# 2497              Jurassic Park III: Island Attack      GBA  2001.0   NaN
# 3353                   The Godfather: Dons Edition      PS3  2007.0   NaN
# 3363                  Ski-Doo Snowmobile Challenge     X360  2009.0   NaN
# 3470            Batman Beyond: Return of the Joker      N64  2000.0   NaN
# 3515      Princess Saver! Eternal Love for My Lady      PS2  2010.0   NaN
# 3932                             MVP Baseball 2004      PS2  2004.0   NaN
# 4148                           Grand Theft Auto IV       PC  2008.0   NaN
# 4349                     Brain Quest: Grades 5 & 6       DS  2008.0   NaN
# 4545             Dragon Ball Z: Ultimate Tenkaichi     X360  2011.0   NaN
# 4598                                     Wii Party      Wii  2010.0   NaN
# 4935                              Astonishia Story      PSP  2006.0   NaN
# 5668                                  Chrono Cross       PS  1999.0   NaN
# 5713                  Back to the Future: The Game     XOne  2015.0   NaN
# 5945                             Medabots: Metabee      GBA  2002.0   NaN
# 6798                                  UFO: Trilogy       PC  2007.0   NaN
# 7143                  Largo Winch .// Commando Sar       PS  2002.0   NaN
# 7336                                 Madden NFL 11      PS2  2010.0   NaN
# 7526                               Ukiyo no Shishi      PS3  2015.0   NaN
# 7797                     Myth Makers: Orbs of Doom      Wii  2007.0   NaN
# 9488                             Final Fantasy XII      PS2  2006.0   NaN
# 10432        The Mummy: Tomb of the Dragon Emperor      Wii  2008.0   NaN
# 10501                      Bakemonogatari Portable      PSP  2012.0   NaN
# 10874            Karaoke Revolution Glee: Volume 3      Wii  2011.0   NaN
# 11050                                 Puppy Palace       DS  2008.0   NaN
# 11063                                     Yakuza 3      PS3  2009.0   NaN
# 11268            Cloudy With a Chance of Meatballs      PS3  2009.0   NaN
# 11496                                     F-Zero X      N64  1998.0   NaN
# 11668  The History Channel: Battle for the Pacific      Wii  2007.0   NaN
# 11699                               Time Travelers      PSV  2012.0   NaN
# 12314                                   Ice Hockey     2600  1980.0   NaN
# 12331                           Onimusha: Warlords      PS2  2001.0   NaN
# 12340                             Virtual Chess 64      N64  1998.0   NaN
# 12870         PQ2: Practical Intelligence Quotient      PSP  2006.0   NaN
# 12982                                  Urban Chaos       PS  1999.0   NaN
# 13348        Treasure Report: Kikai Jikake no Isan       DS  2011.0   NaN
# 14930                            Skylanders Giants      PS3  2012.0   NaN
# 15077                   Myth Makers: Super Kart GP      Wii  2007.0   NaN
# 15211                    James Bond 007: Nightfire       XB  2002.0   NaN
# 15426            WarioWare, Inc.: Mega Party Game$       GC  2003.0   NaN
# 15526                                   Bloodborne      PS4  2015.0   NaN
# 16091                       Brain Boost: Beta Wave       DS  2005.0   NaN
# 16431            Cars: Mater-National Championship     X360  2007.0   NaN
# 16555                          Apache: Air Assault       PC  2010.0   NaN
# 16587                 Need for Speed Underground 2       XB  2004.0   NaN
#
#                           Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 50      Sony Computer Entertainment     0.52     0.01     0.12        0.05
# 408                    Midway Games     0.37     0.11        0        0.02
# 1328                Electronic Arts     0.49     0.15        0        0.02
# 1582    Sony Computer Entertainment        0     0.04        0        0.57
# 1971                       Nintendo    5170K     4.05     4.34        0.79
# 2043                    Pioneer LDC     0.23     0.16        0        0.03
# 2497   Konami Digital Entertainment     0.13     0.05        0           0
# 3353                Electronic Arts     0.25     0.02        0        0.03
# 3363                   Valcon Games     0.03        0        0           0
# 3470                        Ubisoft     0.07     0.02        0           0
# 3515                        Comfort        0        0     0.02           0
# 3932                Electronic Arts      1.1     0.06        0        0.18
# 4148           Take-Two Interactive     0.01     0.79        0        0.08
# 4349                Electronic Arts     0.11        0        0        0.01
# 4545             Namco Bandai Games     0.39      0.1     0.01        0.04
# 4598                       Nintendo     1.79     3.53     2.49        0.68
# 4935                        Ubisoft     0.03        0        0           0
# 5668                     SquareSoft     0.62     0.42     0.69        0.12
# 5713                 Telltale Games        0     0.02        0           0
# 5945                        Natsume     0.04     0.01        0           0
# 6798                        Unknown        0     0.02        0           0
# 7143                        Ubisoft     0.01     0.01        0           0
# 7336                Electronic Arts     0.41     0.02        0        0.07
# 7526             Namco Bandai Games        0        0     0.03           0
# 7797                 Popcorn Arcade     0.05        0        0           0
# 9488                    Square Enix     1.88        0     2.33        1.74
# 10432                 Vivendi Games     0.08        0        0        0.01
# 10501            Namco Bandai Games        0        0     0.05           0
# 10874  Konami Digital Entertainment     0.24     0.04        0        0.02
# 11050                       Ubisoft     0.35        0        0        0.03
# 11063                          Sega     0.21     0.21     0.62        0.08
# 11268                       Ubisoft     0.09     0.01        0        0.01
# 11496                      Nintendo     0.45     0.33     0.29        0.03
# 11668                    Activision      0.1        0        0        0.01
# 11699                       Level 5        0        0     0.05           0
# 12314                    Activision     0.46     0.03        0        0.01
# 12331            Virgin Interactive     0.99     0.48     1.09        0.14
# 12340                         Titus     0.05     0.01        0           0
# 12870                   D3Publisher     0.04        0        0           0
# 12982             Eidos Interactive     0.06     0.04        0        0.01
# 13348            Namco Bandai Games        0        0     0.05           0
# 14930                    Activision     0.35     0.52        0        0.22
# 15077                Popcorn Arcade     0.01        0        0           0
# 15211               Electronic Arts     0.58     220K        0        0.03
# 15426                      Nintendo      0.2     0.05     0.44        0.02
# 15526   Sony Computer Entertainment        1     0.76     0.26        0.36
# 16091                     505 Games     0.14        0        0        0.01
# 16431                           THQ     0.13        0        0        0.01
# 16555                   Just Flight        0     0.03        0        0.01
# 16587               Electronic Arts     1.38      0.8        0         0.1

# %%
# 1-4-2. Genre 결측치 리스트화(names_list1) 및 수집
# 리스트화

names_list1 = []
for name in df.loc[df.Genre.isna(), 'Name']:
    names_list1.append(name)
names_list1[-3:]

# ['Cars: Mater-National Championship',
#  'Apache: Air Assault',
#  'Need for Speed Underground 2']
# Out:
# ['Cars: Mater-National Championship',
#  'Apache: Air Assault',
#  'Need for Speed Underground 2']

# %%
# Genre 데이터가 결측치인 게임의 Name, Platform 확인
# 각각 names_list1, platforms_list1 로 모아줌

names_list1 = []
platform_list1 = []

for x, y in zip(df.loc[(df.Genre.isna()), 'Name'], df.loc[(df.Genre.isna()), 'Platform']):
    names_list1.append(x)
    platform_list1.append(y)  

genre_nan_df = pd.DataFrame({'Name': names_list1, 'Platform': platform_list1, 'Genre': '0'})
genre_nan_df.head() # genre_nan_df.shape: (50, 3)
# Out:
#                              Name Platform Genre
# 0        Ape Escape: On the Loose      PSP     0
# 1                     NBA Ballers       XB     0
# 2                      NFL Street       XB     0
# 3  SingStar Singalong With Disney      PS2     0
# 4             Pokemon X/Pokemon Y      3DS     0

# %%
# 수집

driver = webdriver.Chrome(ChromeDriverManager().install())

for x in names_list1:
    # name genre로 검색
    driver.get('https://www.google.com/search?q={}'.format(x + " " + "genre"))
    # genre 데이터 입력받기
    genre = input('Genre : ')
    # 입력받은 데이터 저장
    df.loc[((df.Genre.isna()) & (df.Name == x)), 'Genre'] = genre
driver.quit()
df.Genre.isna().sum()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [C:\Users\maeve\.wdm\drivers\chromedriver\win32\103.0.5060.53\chromedriver.exe] found in cache
# C:\Users\maeve\AppData\Local\Temp\ipykernel_12864\2509911167.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# 0

# %%
df.Genre.value_counts()
# Out:
# Action          3308
# Sports          2347
# Misc            1737
# Role-Playing    1491
# Shooter         1308
# Adventure       1291
# Racing          1249
# Platform         885
# Simulation       868
# Fighting         848
# Strategy         682
# Puzzle           582
# Shooting           2
# Name: Genre, dtype: int64

# %%
df.loc[df.Genre == 'Shooter', 'Genre'] = 'Shooting' # Shooting 으로 Genre 통일
df.loc[df.Genre == ' Adventure', 'Genre'] = 'Adventure' # ' Adventure'을 'Adventure'로 공백제거, 통일
df.Genre.value_counts() # df.Genre.isna().sum(): 0
# Out:
# Action          3308
# Sports          2347
# Misc            1737
# Role-Playing    1491
# Shooting        1310
# Adventure       1291
# Racing          1249
# Platform         885
# Simulation       868
# Fighting         848
# Strategy         682
# Puzzle           582
# Name: Genre, dtype: int64

# %%
df[df.Genre.str.contains('Adventure')]
# Out:
#                                                     Name Platform    Year  \
# 2         Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010.0
# 8                                             Imabikisou      PS3  2007.0
# 42     Phoenix Wright: Ace Attorney - Trials and Trib...       DS  2007.0
# 68                 Sherlock Holmes: Crimes & Punishments      PS4  2014.0
# 93                  Pac-Man and the Ghostly Adventures 2      PS3  2014.0
# ...                                                  ...      ...     ...
# 16562          Sherlock Holmes: The Mystery of the Mummy       DS  2009.0
# 16565                            Toshochu: Run for Money      3DS  2012.0
# 16580              Captain Morgane and the Golden Turtle       DS  2012.0
# 16585                                    Pokemon Channel       GC  2003.0
# 16590            White Album: Tsuzurareru Fuyu no Omoide      PS3  2010.0
#
#            Genre               Publisher NA_Sales EU_Sales JP_Sales  \
# 2      Adventure               Alchemist        0        0     0.02
# 8      Adventure                    Sega        0        0     0.04
# 42     Adventure                  Capcom     0.33     0.05     0.25
# 68     Adventure  Focus Home Interactive     0.08     0.14        0
# 93     Adventure      Namco Bandai Games     0.05     0.04        0
# ...          ...                     ...      ...      ...      ...
# 16562  Adventure  Focus Home Interactive     0.06      0.3        0
# 16565  Adventure      Namco Bandai Games        0        0     0.62
# 16580  Adventure      Reef Entertainment        0     0.03       0M
# 16585  Adventure                Nintendo     0.24     0.06     0.07
# 16590  Adventure               Aqua Plus        0        0     0.05
#
#       Other_Sales
# 2               0
# 8               0
# 42           0.04
# 68           0.05
# 93           0.02
# ...           ...
# 16562        0.04
# 16565           0
# 16580           0
# 16585        0.01
# 16590           0
#
# [1291 rows x 9 columns]

# %%
# 1-5. Publisher 결측치 수집
# 1-5-1. Publisher 결측치 이름 수집

names_list2 = []
for name in df.loc[df.Publisher.isna(), 'Name']:
    names_list2.append(name)
names_list2[-3:]

# ['Dream Dancer',
#  'Bound By Flame',
#  'Super Robot Wars OG Saga: Masou Kishin II - Revelation of Evil God']
# Out:
# ['Dream Dancer',
#  'Bound By Flame',
#  'Super Robot Wars OG Saga: Masou Kishin II - Revelation of Evil God']

# %%
# Publisher 데이터가 결측치인 게임의 Name, Platform 확인
# 각각 names_list2, platforms_list2 로 모아줌

names_list2 = []
platform_list2 = []

for x, y in zip(df.loc[(df.Publisher.isna()), 'Name'], df.loc[(df.Publisher.isna()), 'Platform']):
    names_list2.append(x)
    platform_list2.append(y)  

pub_nan_df = pd.DataFrame({'Name': names_list2, 'Platform': platform_list2, 'Publisher': '0'})
pub_nan_df.head() # pub_nan_df.shape: (58, 3)
# Out:
#                                                 Name Platform Publisher
# 0                                 UK Truck Simulator       PC         0
# 1     All Grown Up!: Game Boy Advance Video Volume 1      GBA         0
# 2  Teenage Mutant Ninja Turtles: Game Boy Advance...      GBA         0
# 3  Nicktoons Collection: Game Boy Advance Video V...      GBA         0
# 4                     Monster Hunter Frontier Online      PS3         0

# %%
df.Publisher.unique()
# Out:
# array(['Destineer', 'Namco Bandai Games', 'Alchemist', 'Zoo Games',
#        'D3Publisher', 'Konami Digital Entertainment', 'Deep Silver',
#        'Tecmo Koei', 'Sega', 'THQ', 'Empire Interactive', 'Ubisoft',
#        'Paradox Interactive', '505 Games', 'Tomy Corporation',
#        'Eidos Interactive', 'Microsoft Game Studios',
#        'Nippon Ichi Software', 'Kalypso Media', 'Electronic Arts',
#        'Sony Computer Entertainment', 'Activision',
#        'Tru Blu Entertainment', 'Warner Bros. Interactive Entertainment',
#        'Midway Games', 'Mindscape', 'Wargaming.net', 'Capcom',
#        'Acclaim Entertainment', 'Unknown', 'Nintendo',
#        'Disney Interactive Studios', 'Crave Entertainment', 'Sunflowers',
#        'Arc System Works', 'Milestone S.r.l', 'Kamui', 'Hudson Soft',
#        'Square Enix', 'Focus Home Interactive', 'Take-Two Interactive',
#        'Game Factory', 'Takara Tomy', 'SquareSoft', 'Global Star',
#        'Infogrames', 'GT Interactive', 'Storm City Games',
#        'Gathering of Developers', 'Giza10', 'Imagineer', 'Atari',
#        'SouthPeak Games', 'Graffiti', 'Banpresto', 'Gust',
#        'From Software', 'TDK Mediactive', '5pb', 'Nobilis', 'Taito',
#        'Foreign Media Games', 'Nippon Columbia', 'Vivendi Games',
#        'Codemasters', 'Bethesda Softworks', '3DO', 'Enix Corporation',
#        'Ignition Entertainment', 'ASCII Media Works',
#        'Virgin Interactive', 'Easy Interactive', 'SCi', 'Idea Factory',
#        'Jaleco', 'Majesco Entertainment', 'ArtDink', 'System Soft',
#        'CBS Electronics', 'Kaga Create', 'Phantagram',
#        'Zoo Digital Publishing', 'BAM! Entertainment',
#        'Jester Interactive', 'Quinrose', 'Game Arts', 'Headup Games',
#        'Rising Star Games', 'TGL', 'Gremlin Interactive Ltd', nan,
#        'Avanquest', '10TACLE Studios', 'Activision Value', 'responDESIGN',
#        'Rage Software', 'Little Orbit', 'Marvelous Interactive',
#        'Marvelous Entertainment', 'Kadokawa Shoten', 'Compile Heart',
#        'Takara', 'Seta Corporation', 'Comfort', 'LucasArts',
#        'NEC Interchannel', 'SNK Playmore', 'Russel', 'FuRyu',
#        'dramatic create', 'Koch Media', 'LSP Games', 'Microids',
#        'Psygnosis', 'Culture Brain', 'Saurus', 'Hackberry',
#        'FuRyu Corporation', 'Midas Interactive Entertainment',
#        'Office Create', 'Media Factory', 'Asylum Entertainment',
#        'ValuSoft', 'Universal Interactive', 'bitComposer Games',
#        'Rocket Company', 'Atlus', 'Number None', 'Genki', 'Compile',
#        'Telltale Games', 'UFO Interactive', 'Magix', 'NewKidCo', 'Coleco',
#        'TopWare Interactive', 'Harmonix Music Systems', 'Sting',
#        'Hudson Entertainment', 'Ghostlight', 'Sunsoft', 'Spike',
#        'Home Entertainment Suppliers', 'Screenlife', 'Moss',
#        'Ubisoft Annecy', 'Oxygen Interactive', 'Kemco', 'P2 Games',
#        'Datam Polystar', 'Palcom', 'Enterbrain', 'Starfish',
#        '20th Century Fox Video Games', 'Xplosiv', 'Scholastic Inc.',
#        'Phenomedia', 'GOA', 'Yamasa Entertainment', 'MTV Games', 'PQube',
#        'Aqua Plus', 'Daedalic', 'ASCII Entertainment', 'Nordic Games',
#        'Ongakukan', 'Interchannel-Holon', 'Avanquest Software',
#        'Black Bean Games', 'DTP Entertainment', 'NEC',
#        'Black Label Games', 'O3 Entertainment', 'Micro Cabin',
#        'Marvel Entertainment', 'Telegames', 'Hasbro Interactive',
#        'Tigervision', 'Funsta', 'Kadokawa Games', 'Success', 'Level 5',
#        'Sammy Corporation', 'Axela', 'Milestone S.r.l.',
#        'Agatsuma Entertainment', 'Vap', 'System 3 Arcade Software',
#        'Broccoli', 'Media Rings', 'Interplay', 'Swing! Entertainment',
#        'Fox Interactive', 'Aques', 'DreamCatcher Interactive',
#        'General Entertainment', 'Sony Online Entertainment', 'Shogakukan',
#        'Rebellion', 'Starpath Corp.', 'Square', 'Quintet', 'Touchstone',
#        'Mumbo Jumbo', 'Epoch', 'Parker Bros.', 'TDK Core',
#        'Mattel Interactive', 'Prototype', 'Merscom LLC',
#        'Insomniac Games', 'Human Entertainment', 'Nichibutsu',
#        'Playlogic Game Factory', 'Ocean',
#        'Cloud Imperium Games Corporation', 'Funcom',
#        'Hamster Corporation', 'Idea Factory International',
#        'Destination Software, Inc', 'DHM Interactive', 'Myelin Media',
#        'SNK', 'Licensed 4U', 'GSP', 'City Interactive', 'PopCap Games',
#        'AQ Interactive', 'Victor Interactive', 'Titus',
#        'Excalibur Publishing', 'Popcorn Arcade', 'Valcon Games', 'Mojang',
#        'Metro 3D', 'Vatical Entertainment', 'ChunSoft', 'Astragon',
#        'CyberFront', 'Big Ben Interactive', 'Big Fish Games',
#        'Conspiracy Entertainment', 'Naxat Soft', 'Paon Corporation',
#        'Bigben Interactive', 'MediaQuest', 'Blast! Entertainment Ltd',
#        'Data Design Interactive', 'Nexon', 'Neko Entertainment', 'iWin',
#        'Introversion Software', 'GameMill Entertainment', 'Play It',
#        'Asgard', 'Pioneer LDC', 'ASC Games', '989 Studios', 'MTO',
#        'Mercury Games', 'Navarre Corp', 'Boost On', 'Maxis', 'Rondomedia',
#        'MC2 Entertainment', 'CDV Software Entertainment', 'Funbox Media',
#        'Angel Studios', 'Xseed Games', 'Performance Designed Products',
#        'Sony Computer Entertainment Europe', 'Wanadoo',
#        'Lexicon Entertainment', 'Aruze Corp', 'Virtual Play Games',
#        'Seventh Chord', 'JoWood Productions', 'Pinnacle',
#        'Iceberg Interactive', 'Agetec', 'Mastertronic', 'Vic Tokai',
#        'ITT Family Games', 'Gameloft', 'Sony Music Entertainment',
#        'Mastiff', 'imageepoch Inc.', 'Arena Entertainment', 'TOHO',
#        'Bomb', 'Interchannel', 'LEGO Media', 'Grand Prix Games', 'Mitsui',
#        'Zushi Games', 'O-Games', 'NCSoft', 'Arika', 'CPG Products',
#        'Slitherine Software', 'Alternative Software', 'Data Age',
#        'Plenty', 'PlayV', 'Karin Entertainment', 'Knowledge Adventure',
#        'Valve Software', 'Gotham Games', 'Genterprise', 'G.Rev',
#        'Kids Station', 'Asmik Ace Entertainment',
#        'Monte Christo Multimedia', 'Cave', 'Milestone', 'Views',
#        'Benesse', 'Encore', 'XS Games', 'Avalon Interactive',
#        'EON Digital Entertainment', 'Mentor Interactive',
#        'Irem Software Engineering', 'Brash Entertainment',
#        'Flashpoint Games', 'Imagic', 'KID', 'Media Works', 'Altron',
#        'Mirai Shounen', 'SSI', 'Strategy First',
#        'Ascaron Entertainment GmbH', 'Natsume', 'Warashi', 'IE Institute',
#        'Warp', 'Mad Catz', 'NCS', 'The Learning Company', 'Sweets',
#        'Game Life', 'HMH Interactive', 'Xicat Interactive',
#        'Rebellion Developments', 'Yeti', 'Ackkstudios',
#        'CokeM Interactive', 'Evolved Games', 'Video System',
#        'Aksys Games', 'PM Studios', 'Coconuts Japan',
#        'Sunrise Interactive', 'Bohemia Interactive', "Yuke's", 'Tivola',
#        'GungHo', 'Tradewest', 'Tommo', 'GN Software', 'Gaga', 'Aspyr',
#        'Trion Worlds', 'Revolution (Japan)', 'Misawa', 'Pack-In-Video',
#        'Hect', 'TalonSoft', 'Aerosoft', 'RTL', 'Minato Station',
#        'Activision Blizzard', 'Playmates', 'CTO SpA',
#        'BMG Interactive Entertainment', 'Media Entertainment',
#        'Hip Interactive', 'Acquire', 'Jack of All Games',
#        'The Adventure Company', 'Epic Games', 'DSI Games', 'Fortyfive',
#        'Indie Games', 'NovaLogic', 'Happinet', 'Reef Entertainment',
#        'Masque Publishing', 'Imadio', 'Microprose', 'Falcom Corporation',
#        'Square EA', 'Red Storm Entertainment', 'Dusenberry Martin Racing',
#        'Sonnet', 'Tripwire Interactive', 'RED Entertainment',
#        'Global A Entertainment', 'Athena', 'Groove Games',
#        'Mud Duck Productions', 'Ertain', 'System 3', 'Marvelous Games',
#        'Gamecock', 'Panther Software', 'Playmore', 'Vir2L Studios',
#        'mixi, Inc', 'HAL Laboratory', 'BushiRoad', 'Jorudan', 'JVC',
#        'Alawar Entertainment', 'Inti Creates', 'Laguna', 'NetRevo',
#        'Daedalic Entertainment', 'Time Warner Interactive',
#        'Slightly Mad Studios', 'Max Five', 'Devolver Digital', 'CCP',
#        'Flight-Plan', 'Quelle', 'Dorart', 'ESP', 'Answer Software',
#        'Phoenix Games', 'Yumedia', 'Elite', 'Elf', 'Nordcurrent', 'New',
#        'Paon', 'Nihon Falcom Corporation', 'Commseed', 'BPS', 'Tryfirst',
#        'FunSoft', 'Legacy Interactive', 'Princess Soft',
#        'Graphsim Entertainment', 'Creative Core',
#        'Electronic Arts Victor', 'Mamba Games', 'Her Interactive',
#        'Maximum Family Games', 'DreamWorks Interactive', 'Detn8 Games',
#        'Universal Gamex', 'Hearty Robin', 'GameTek', 'RedOctane',
#        'U.S. Gold', 'Wizard Video Games',
#        'Sony Computer Entertainment America', 'Telstar',
#        'Yacht Club Games', 'PopTop Software', 'Experience Inc.',
#        'Michaelsoft', 'Gakken', 'T&E Soft', 'Origin Systems',
#        'Gainax Network Systems', 'inXile Entertainment',
#        'Focus Multimedia', 'SCS Software', 'Hello Games',
#        'Essential Games', 'Xing Entertainment', 'Riverhillsoft',
#        '1C Company', 'Data East', 'Mycom', '7G//AMES', 'DigiCube', 'Fuji',
#        'Simon & Schuster Interactive', 'Pow',
#        'Pacific Century Cyber Works', 'Extreme Entertainment Group',
#        'Image Epoch', 'Core Design Ltd.', 'Otomate', 'Piacci', 'ASK',
#        'WayForward Technologies', 'Pack In Soft', 'Red Orb', 'Takuyo',
#        'UIG Entertainment', 'Crystal Dynamics', 'Blue Byte', 'Rain Games',
#        'Gamebridge', 'New World Computing', 'fonfun', 'Berkeley',
#        'Interworks Unlimited, Inc.', 'Societa', 'On Demand',
#        'Crimson Cow', 'Griffin International', 'Visco', 'Syscom',
#        'King Records', 'Tetris Online', 'EA Games', 'Locus',
#        'Paradox Development', 'Nippon Telenet', 'Accolade', 'id Software',
#        'HuneX', 'Interplay Productions', 'Evolution Games',
#        'Kokopeli Digital Studios', 'Ascaron Entertainment', '989 Sports',
#        'Illusion Softworks', 'Kando Games', 'Pony Canyon', 'Intergrow',
#        'Glams', 'Nitroplus', 'Zenrin', 'Team17 Software', 'Fields',
#        'Havas Interactive', '49Games', 'Alvion', 'Quest', 'Imageworks',
#        'Stainless Games', 'Daito', 'Enjoy Gaming ltd.', 'Aria',
#        'Kool Kizz', 'Sold Out', 'Magical Company', 'Imax', 'Summitsoft',
#        'Cygames', 'Men-A-Vision', 'Adeline Software',
#        'Revolution Software', 'Valve', 'Codemasters Online', 'TYO',
#        'Phantom EFX', 'Liquid Games', 'American Softworks', 'SPS',
#        'Sears', 'Edia', 'Nippon Amuse', 'Asmik Corp', 'MLB.com',
#        'White Park Bay Software', 'Abylight', 'Ecole', 'TechnoSoft',
#        'Culture Publishers', 'Ivolgamus', '2D Boy',
#        'Technos Japan Corporation', 'Giga', 'Westwood Studios',
#        'UEP Systems', 'KSS', 'Type-Moon', 'Ultravision',
#        'Lighthouse Interactive', 'NDA Productions', 'Mystique',
#        'Just Flight'], dtype=object)

# %%
# 1-5-2. Publisher 결측치 수집
driver = webdriver.Chrome(ChromeDriverManager().install())

publisher_list = []

for x in names_list2:
    # name publisher로 검색
    driver.get('https://www.google.com/search?q={}'.format(x + " " + "publisher"))
    # publisher 입력받기
    publisher = input('publisher : ')
    # 입력받은 값 리스트에 저장
    publisher_list.append(publisher)
driver.quit()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [C:\Users\maeve\.wdm\drivers\chromedriver\win32\103.0.5060.53\chromedriver.exe] found in cache
# C:\Users\maeve\AppData\Local\Temp\ipykernel_12864\423769202.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
# Publisher 결측치 채우기
df.loc[df.Publisher.isna(), 'Publisher'] = publisher_list
df.Publisher.isna().sum()
# Out:
# 0

# %%
df.loc[df.Publisher == 'Bandai Namco Games', 'Publisher'] = 'Namco Bandai Games'
df.loc[df.Publisher == 'Namco Banai Games', 'Publisher'] = 'Namco Bandai Games'
df.loc[df.Publisher == 'Majesco', 'Publisher'] = 'Majesco Entertainment'
df.Publisher.value_counts()
# Out:
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               935
# Ubisoft                          921
# Konami Digital Entertainment     833
#                                 ...
# Quelle                             1
# Phantagram                         1
# Answer Software                    1
# Phoenix Games                      1
# Just Flight                        1
# Name: Publisher, Length: 590, dtype: int64

# %%
df[df.Publisher == 'Majesco Entertainment'].count()
# Out:
# Name           111
# Platform       111
# Year           111
# Genre          111
# Publisher      111
# NA_Sales       111
# EU_Sales       111
# JP_Sales       111
# Other_Sales    111
# dtype: int64

# %%
# Publisher 데이터명 통일
df[df.Publisher.str.contains('Namco')]
# Out:
#                                                     Name Platform    Year  \
# 1                                         The Munchables      Wii  2009.0
# 17                  Hajime no Ippo: The Fighting! (2014)      PS3  2014.0
# 64                                       SD Gundam Force      GBA  2004.0
# 81                                 Treasures of the Deep       PS  1997.0
# 82              Mobile Suit Gundam: Perfect One Year War       PS  1997.0
# ...                                                  ...      ...     ...
# 16519                            Pro Yakyuu Famista 2011      3DS  2011.0
# 16520                            Snoopy vs the Red Baron      PSP  2006.0
# 16523  Gotouchi Tetsudou: Gotouchi Chara to Nihon Zen...      3DS  2014.0
# 16553  Crayon Shin-Chan Shokkugan! Densetsu o Yobu Om...       DS  2010.0
# 16565                            Toshochu: Run for Money      3DS  2012.0
#
#            Genre           Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 1         Action  Namco Bandai Games     0.17        0        0        0.01
# 17        Sports  Namco Bandai Games        0        0     0.03           0
# 64      Shooting  Namco Bandai Games     0.01        0        0          0M
# 81        Action  Namco Bandai Games      0.1     0.07        0        0.01
# 82      Strategy  Namco Bandai Games        0        0     0.14        0.01
# ...          ...                 ...      ...      ...      ...         ...
# 16519     Sports  Namco Bandai Games        0        0     0.06           0
# 16520  Adventure  Namco Bandai Games     0.04        0        0           0
# 16523       Misc  Namco Bandai Games        0        0     0.12           0
# 16553     Action  Namco Bandai Games        0        0     0.09           0
# 16565  Adventure  Namco Bandai Games        0        0     0.62           0
#
# [935 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         16598 non-null  object
#  1   Platform     16598 non-null  object
#  2   Year         16598 non-null  float64
#  3   Genre        16598 non-null  object
#  4   Publisher    16598 non-null  object
#  5   NA_Sales     16598 non-null  object
#  6   EU_Sales     16598 non-null  object
#  7   JP_Sales     16598 non-null  object
#  8   Other_Sales  16598 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 1.1+ MB

# %%
# 1-6. Sales 데이터 확인
# 1-6-1. Sales 이상값 확인
df.NA_Sales.value_counts()
# Out:
# 0        4443
# 0.02      537
# 0.01      536
# 0.03      528
# 0.05      523
#          ...
# 6.91        1
# 3.88        1
# 4.14        1
# 1.11M       1
# 4.18        1
# Name: NA_Sales, Length: 494, dtype: int64

# %%
df.NA_Sales.value_counts() # Name: NA_Sales, Length: 494, dtype: int64
df.NA_Sales.unique() # 숫자 외에 M, K 들어있는 데이터 확인
# Out:
# array(['0.04', '0.17', '0', '0.12', '0.02', '0.07', '480K', '0.14',
#        '0.01', '0.57', '0.06', '0.08', '0.48', '0.03', '0.05', '1.93',
#        '0.29', '0.19', '0.3', '0.26', '0.11', '0.18', '0.33', '0.51',
#        '60K', '0.13', '0.52', '0.34', '0.25', '0.41', '0.22', '0.35',
#        '0.1', '0.67', '0.59', '0.36', '0.21', '1.19', '5.91', '1.98',
#        '0.09', '0K', '0.5', '0.94', '0.16', '0.63', '0.43', '0.2', '1.23',
#        '0.44', '0.42', '0.97', '2.67', '0.28', '6.05', '0.47', '0.49',
#        '0.62', '0.24', '0.72', '1.74', '0.46', '0.65', '0.32', '1.53',
#        '0.23', '0.53', '0.37', '1.26', '0.39', '0.58', '1.94', '2.31',
#        '1.03', '0.82', '0.4', '0.93', '0.56', '0.96', '1.64', '0.69',
#        '1.25', '0.27', '0.92', '0.58M', '1.24', '0.25M', '0.86', '0.73',
#        '0.55', '1.54', '1.02', '1.27', '0.54', '0.15', '1.09', '3.44',
#        '2.29', '0.88', '5.55M', '1.37', '2.3', '0.99', '1.15', '0.98',
#        '0.75', '0.74', '0.7', '0.14M', '0.45', '1.2', '1.41', '0.68',
#        '1.23M', '1.56', '0.31', '1.45', '1.11', '2.9', '0M', '0.83',
#        '0.78', '3.38', '0.64', '1.08', '0.38', '1.47', '0.06M', '0.77',
#        '1.05', '6.85', '3.83', '3.79', '1.13M', '0.9', '3.78', '1.89',
#        '1.17', '4.03', '0.89', '0.61', '0.71', '23.2', '1.44', '1.31',
#        '3.06', '3.14', '1.66', '0.79', '1.39', '0.31M', '490K', '1.85',
#        '0.76', '2.06', '1.36', '1.3', '1.06', '1.1', '240K', '2.08',
#        '1.04', '0.66', '2.64', '1.58', '0.05M', '3.11', '4.34', '150K',
#        '1.78', '0.85', '2.91', '0.13M', '1', '1.01', '4100K', '5170K',
#        '1.07', '3.8', '2.5', '2.2', '1.5', '1.91', '0.95', '2.03', '2.1',
#        '1.4', '3.18', '1.73', '1.12', '1.72', '2.05', '1.63', '1.22',
#        '1.13', '1.49', '2.55', '0.87', '0.81', '0.6', '0.61M', '2.62',
#        '0.84', '2.38', '1.32', '20K', '3.02', '1.75', '2.02', '1.82',
#        '1.68', '9.03', '2.56', '1.87', '2.65', '1.48', '3.19', '1.33',
#        '41.49', '30K', '1.16', '1.21', '0.02M', '2.52', '2.28', '5.99',
#        '14.03', '2.93', '2.45', '0.11M', '2.14', '2.99', '0.01M', '2.6',
#        '1.35', '0.36M', '50K', '1.28', '2.95', '70K', '1.86', '15.75',
#        '1.18', '1.42', '8.94', '7.01', '190K', '1.57', '1.62', '0.91',
#        '0.8', '2.09', '1.96', '1.52', '2.39', '1.79', '0.21M', '0.43M',
#        '2.19', '1.43', '1.76', '2.78', '1.3M', '1.71', '29.08', '3.13',
#        '3.1', '4.99', '4.23', '2.35', '14.97', '1.65', '1210K', '2.26',
#        '3.64', '350K', '2.71', '3.49', '3.33', '1.46', '1.7', '4.4',
#        '4.02', '2.53', '1610K', '2.01', '100K', '1.55', '4.47', '1.9',
#        '2.25', '3.98', '2.51', '1.61', '1.84', '1.81', '170K', '8.41',
#        '2.11', '2.74', '2.42', '3.92', '6.72', '2.54', '4', '0.9M', '40K',
#        '2.12', '7.28', '2.13', '1.59', '1.88', '3.39', '450K', '2.96',
#        '8.52', '2.82', '9.67', '7.97', '8.25', '1.67', '1.51', '6.91',
#        '3.88', '3.27', '4.14', '1.92', '220K', '1.29', '2.04', '1.11M',
#        '310K', '0.07M', '2.15', '6.16', '4.09', '11.38', '4.26', '1.69',
#        '1.34', '820K', '2.17', '80K', '4.36', '2.8', '290K', '3.05',
#        '130K', '5.39', '2.66M', '2.47', '4.15', '4.46', '1.18M', '11.27',
#        '1.38', '3.66', '4.12', '0.55M', '2.41', '2.57', '2', '2.58',
#        '5.89', '2.18', '1.99', '2.72', '2.36', '120K', '0.08M', '0.22M',
#        '5.77', '3.68', '3.23', '5.84', '9', '2.85', '10.83', '6.82',
#        '3.54', '0.3M', '0.04M', '3.42', '6.99', '1780K', '2930K', '1.14',
#        '2.49', '5.98', '2.33', '1.97', '5.58', '0.15M', '0.1M', '3.7',
#        '2.07', '4.41', '1.83', '0.29M', '4.98', '770K', '10K', '280K',
#        '2.43', '26.93', '6.42', '3.81', '5.57', '9.81', '0.37M', '0.12M',
#        '3.28', '3.74', '540K', '2.66', '9.09', '1.77', '9.63M', '6.06',
#        '4.79', '2.59', '2.48', '0.34M', '2.97', '2.63', '4.74', '9.07',
#        '0.26M', '3.51', '1.6', '5.03', '3.22', '3.01', '2.22', '2.77',
#        '3.25', '550K', '2010K', '5.8', '3.59', '2.4', '1.95', '0.18M',
#        '5.08', '2.84', '15.85', '7.03M', '4.89', '3.24', '4.01', '340K',
#        '2.32', '3.4', '90K', '12.78', '2.21', '3.36', '4.75', '600K',
#        '0.46M', '0.03M', '6.76', '2570K', '3', '4.05', '5.54', '0.72M',
#        '2.75', '3.21', '6.63', '9.43', '3.03', '3.5', '2.7', '0.96M',
#        '9.54', '6.75', '3.63', '270K', '420K', '0.28M', '2.79', '4.21',
#        '2.23', '4.52', '0.45M', '720K', '2.89', '0.53M', '4.76', '470K',
#        '14.59', '320K', '4.18'], dtype=object)

# %%
# NA_Sales 컬럼 문자열에 K가 포함된 데이터 - 'K = 1000$' 확인
# 확인 결과 4가지 Sales 칼럼에서 모두 문자열에 K 포함 확인

df[df.NA_Sales.str.contains('K')] # 100 rows × 9 columns
# Out:
#                                                  Name Platform    Year  \
# 10                                        Ford Racing       PS  2001.0
# 45                       Resident Evil: Revelations 2      PS3  2015.0
# 145                                TOCA Race Driver 3       PC  2006.0
# 878    Tears to Tiara Anecdotes: The Secret of Avalon      PS3  2009.0
# 1086                        Pro Evolution Soccer 2014      3DS  2013.0
# ...                                               ...      ...     ...
# 15647                       Championship Manager 2010       PC  2009.0
# 16194                            Vin Diesel: Wheelman      PS3  2009.0
# 16330                         Midway Arcade Treasures      PS2  2003.0
# 16492                                   Mortal Kombat      PSV  2012.0
# 16578                            Gex: Enter the Gecko       PS  1998.0
#
#           Genre                               Publisher NA_Sales EU_Sales  \
# 10       Racing                      Empire Interactive     480K    0.33M
# 45       Action                                  Capcom      60K     0.08
# 145      Racing                             Codemasters       0K     0.02
# 878    Strategy                               Aqua Plus       0K        0
# 1086     Action            Konami Digital Entertainment       0K        0
# ...         ...                                     ...      ...      ...
# 15647    Sports                       Eidos Interactive       0K     0.01
# 16194    Racing                                 Ubisoft     120K     0.15
# 16330      Misc                            Midway Games     720K     0.56
# 16492  Fighting  Warner Bros. Interactive Entertainment     470K     0.18
# 16578  Platform           BMG Interactive Entertainment     320K     0.22
#
#       JP_Sales Other_Sales
# 10          0K        0.06
# 45        0.16        0.03
# 145          0           0
# 878       0.04           0
# 1086      0.19           0
# ...        ...         ...
# 15647        0           0
# 16194        0        0.06
# 16330        0        0.19
# 16492        0        0.12
# 16578        0        0.04
#
# [100 rows x 9 columns]

# %%
# NA_Sales 컬럼 문자열에 M이 포함된 데이터 - 'M = 100만$' 확인
# 확인 결과 4가지 Sales 칼럼에서 모두 문자열에 M 포함 확인
df[df.NA_Sales.str.contains('M')] # 100 rows × 9 columns
# Out:
#                                              Name Platform    Year     Genre  \
# 447                    Medal of Honor: Warfighter     X360  2012.0    Action
# 458                                       F1 2010      PS3  2010.0    Racing
# 577                                 Mario Kart 64      N64  1996.0    Racing
# 625                                    The Hobbit      GBA  2003.0  Platform
# 672    Star Wars The Clone Wars: Lightsaber Duels      Wii  2008.0    Action
# ...                                           ...      ...     ...       ...
# 15986                 Juiced 2: Hot Import Nights       PC  2007.0    Racing
# 16152                       Taiko no Tatsujin Wii      Wii  2008.0      Misc
# 16169                    Medal of Honor: Airborne     X360  2007.0  Shooting
# 16408               NASCAR 06: Total Team Control      PS2  2005.0    Racing
# 16482            Super Robot Taisen F Kanketsuhen      SAT  1998.0  Strategy
#
#                 Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 447       Electronic Arts    0.58M     0.47     0.01         0.1
# 458           Codemasters    0.25M     0.76     0.08        0.27
# 577              Nintendo    5.55M     1.94     2.23        0.15
# 625         Vivendi Games    0.14M     0.05        0           0
# 672             LucasArts    1.23M      0.3        0        0.14
# ...                   ...      ...      ...      ...         ...
# 15986                 THQ       0M     0.01        0           0
# 16152  Namco Bandai Games       0M        0     0.67           0
# 16169     Electronic Arts    0.45M     0.53     0.01        0.12
# 16408     Electronic Arts    0.53M     0.02        0        0.09
# 16482           Banpresto       0M        0     0.55           0
#
# [100 rows x 9 columns]

# %%
# K, M에 대해 표기 통일해주도록 함 (Sales 데이터 전처리)

sales_col = df.columns[5:]
sales_col
# Out:
# Index(['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales'], dtype='object')

# %%
sales_col = df.columns[5:]
sales_col # Index(['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales'], dtype='object')

NA_K_index = df[df.NA_Sales.str.contains('K')].index # NA_Sales 칼럼에서 문자열에 K 혹은 M이 포함된 데이터의 인덱스 각각 저장
NA_M_index = df[df.NA_Sales.str.contains('M')].index 

for col in sales_col: # 4개 Sales 칼럼에 공통으로 적용하는 for 문 생성
    loc_k = df.loc[df[col].str.contains('K'), col] # 4개 Sales 칼럼에서 K 포함된 데이터 위치 저장
    loc_m = df.loc[df[col].str.contains('M'), col] # 4개 Sales 칼럼에서 M 포함된 데이터 위치 저장
    loc_k = loc_k.str.replace('K', '').astype(float) / 1000 # K 빼주고 1000으로 나누어줌 (데이터타입: object > 실수)
    loc_m = loc_m.str.replace('M', '').astype(float) # M 빼줌 (데이터타입: object > 실수)
    
    df.loc[df[col].str.contains('K'), col] = loc_k.astype(str) # 기존 type인 string으로 바꾸어줌
    df.loc[df[col].str.contains('M'), col] = loc_m.astype(str)
df.loc[NA_K_index] # 결과값 확인1 (4개 Sales 칼럼 단위 모두 100만$)
# Out:
#                                                  Name Platform    Year  \
# 10                                        Ford Racing       PS  2001.0
# 45                       Resident Evil: Revelations 2      PS3  2015.0
# 145                                TOCA Race Driver 3       PC  2006.0
# 878    Tears to Tiara Anecdotes: The Secret of Avalon      PS3  2009.0
# 1086                        Pro Evolution Soccer 2014      3DS  2013.0
# ...                                               ...      ...     ...
# 15647                       Championship Manager 2010       PC  2009.0
# 16194                            Vin Diesel: Wheelman      PS3  2009.0
# 16330                         Midway Arcade Treasures      PS2  2003.0
# 16492                                   Mortal Kombat      PSV  2012.0
# 16578                            Gex: Enter the Gecko       PS  1998.0
#
#           Genre                               Publisher NA_Sales EU_Sales  \
# 10       Racing                      Empire Interactive     0.48     0.33
# 45       Action                                  Capcom     0.06     0.08
# 145      Racing                             Codemasters      0.0     0.02
# 878    Strategy                               Aqua Plus      0.0        0
# 1086     Action            Konami Digital Entertainment      0.0        0
# ...         ...                                     ...      ...      ...
# 15647    Sports                       Eidos Interactive      0.0     0.01
# 16194    Racing                                 Ubisoft     0.12     0.15
# 16330      Misc                            Midway Games     0.72     0.56
# 16492  Fighting  Warner Bros. Interactive Entertainment     0.47     0.18
# 16578  Platform           BMG Interactive Entertainment     0.32     0.22
#
#       JP_Sales Other_Sales
# 10         0.0        0.06
# 45        0.16        0.03
# 145          0           0
# 878       0.04           0
# 1086      0.19           0
# ...        ...         ...
# 15647        0           0
# 16194        0        0.06
# 16330        0        0.19
# 16492        0        0.12
# 16578        0        0.04
#
# [100 rows x 9 columns]

# %%
df.loc[NA_M_index] # 결과값 확인2 (4개 Sales 칼럼 단위 모두 100만$)
# Out:
#                                              Name Platform    Year     Genre  \
# 447                    Medal of Honor: Warfighter     X360  2012.0    Action
# 458                                       F1 2010      PS3  2010.0    Racing
# 577                                 Mario Kart 64      N64  1996.0    Racing
# 625                                    The Hobbit      GBA  2003.0  Platform
# 672    Star Wars The Clone Wars: Lightsaber Duels      Wii  2008.0    Action
# ...                                           ...      ...     ...       ...
# 15986                 Juiced 2: Hot Import Nights       PC  2007.0    Racing
# 16152                       Taiko no Tatsujin Wii      Wii  2008.0      Misc
# 16169                    Medal of Honor: Airborne     X360  2007.0  Shooting
# 16408               NASCAR 06: Total Team Control      PS2  2005.0    Racing
# 16482            Super Robot Taisen F Kanketsuhen      SAT  1998.0  Strategy
#
#                 Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 447       Electronic Arts     0.58     0.47     0.01         0.1
# 458           Codemasters     0.25     0.76     0.08        0.27
# 577              Nintendo     5.55     1.94     2.23        0.15
# 625         Vivendi Games     0.14     0.05        0           0
# 672             LucasArts     1.23      0.3        0        0.14
# ...                   ...      ...      ...      ...         ...
# 15986                 THQ      0.0     0.01        0           0
# 16152  Namco Bandai Games      0.0        0     0.67           0
# 16169     Electronic Arts     0.45     0.53     0.01        0.12
# 16408     Electronic Arts     0.53     0.02        0        0.09
# 16482           Banpresto      0.0        0     0.55           0
#
# [100 rows x 9 columns]

# %%
col = df.columns[5:9] # 4개 Sales 칼럼 col 로 지정
df[col] = df[col].astype(float) # 데이터타입 실수형으로 변경
df = df.astype({'Year': 'int64'})
df.dtypes # 변경 결과 확인
# Out:
# Name            object
# Platform        object
# Year             int64
# Genre           object
# Publisher       object
# NA_Sales       float64
# EU_Sales       float64
# JP_Sales       float64
# Other_Sales    float64
# dtype: object

# %%
df.head() # 지금까지 전처리 수행한 데이터셋 확인
# Out:
#                                              Name Platform  Year      Genre  \
# 0                    Candace Kane's Candy Factory       DS  2008     Action
# 1                                  The Munchables      Wii  2009     Action
# 2  Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010  Adventure
# 3                Deal or No Deal: Special Edition       DS  2010       Misc
# 4       Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010   Platform
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0           Destineer      0.04      0.00      0.00         0.00
# 1  Namco Bandai Games      0.17      0.00      0.00         0.01
# 2           Alchemist      0.00      0.00      0.02         0.00
# 3           Zoo Games      0.04      0.00      0.00         0.00
# 4         D3Publisher      0.12      0.09      0.00         0.04

# %%
# 전체 중복 데이터 확인 (삭제 전 개수 확인!!!!)

df[df.duplicated()]
# 삭제 전 전체 중복 데이터 개수: 1개 (Name: Wii de Asobu: Metroid Prime)

# %%
# 전체 중복 데이터 제거

df = df.drop_duplicates(subset = ['Name', 'Platform', 'Year', 'Publisher', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales'])
# 제거 개수: 1개

# %%
# 전체 중복 데이터 제거 전 df 확인
df.info()

# %%
# 전체 중복 데이터 제거 후 df 확인
df.info()

# 결과: 1개 정상 제거 확인

# %%
# 같은 Name/Platform/Year = 같은 게임인데 판매량이 따로 잡힌 경우 (삭제 전 개수 확인할 것!!!!)
df[df.duplicated(subset = ['Name', 'Platform', 'Year'])]

# 8717: sales 합쳐주고 1개 행 삭제해주도록 함
# 15705: (동일)

# %%
# 3개 칼럼 중복 데이터1 확인
df[(df.Name == 'Madden NFL 13') & (df.Platform == 'PS3') & (df.Year == 2012)]

# %%
# 3개 칼럼 중복 데이터2 확인
df[(df.Name == 'Sonic the Hedgehog') & (df.Platform == 'PS3') & (df.Year == 2003)]

# %%
# 3개 칼럼 중복 데이터1 1개 행 제거 수행 - NFL Madden NFL 13
df = df.drop(df.index[8717])

# %%
# 데이터1 판매량 합쳐주기
df.iloc[7346] = ['Madden NFL 13', 'PS3', 2012, 'Sports', 'Electronic Arts', '2.11', '0.24', '0.0', '0.22']

# %%
df.info()
# 1개 데이터 정상 제거 확인

# %%
# 3개 칼럼 중복 데이터2 1개 행 제거 수행 - Sonic the Hedgehog
df = df.drop(df.index[15705])

# %%
# 데이터2 판매량 합쳐주기
df.iloc[8651] = ['Sonic the Hedgehog', 'PS3', 2003, 'Platform', 'Sega', '0.41', '0.55', '0.04', '0.66']
# df1.iloc[7346] = ['Madden NFL 13', 'PS3', 2012, 'Sports', 'Electronic Arts', '2.11', '0.24', '0.0', '0.22']

# %%
df.info()
# 마지막 중복 데이터 1개 추가 제거 확인
# 16595 non-null 이어야 함

# %%
# 마지막 중복치 drop이므로 인덱스 재설정해줌
df.reset_index(inplace = True)

# %%
df = df.iloc[:,1:] # df = df_original.iloc[:,1:]

# %%
df.info() 
# 최종 수정된 데이터셋: 16595 entries, 0 to 16594

# %%
# 모든 중복치 제거 잘 되었는지 확인
df[df.duplicated()]

# %%
# Global_Sales 칼럼 (전세계 판매금액, 곧 국가별 판매금액의 총합) 추가 하기
global_sales = []
for i in df.index:
    g_sales = df.loc[i, 'NA_Sales' : 'Other_Sales'].sum()
    global_sales.append(round(g_sales, 2))
df['Global_Sales'] = global_sales
df.head()
# Out:
#                                              Name Platform  Year      Genre  \
# 0                    Candace Kane's Candy Factory       DS  2008     Action
# 1                                  The Munchables      Wii  2009     Action
# 2  Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010  Adventure
# 3                Deal or No Deal: Special Edition       DS  2010       Misc
# 4       Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010   Platform
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0           Destineer      0.04      0.00      0.00         0.00          0.04
# 1  Namco Bandai Games      0.17      0.00      0.00         0.01          0.18
# 2           Alchemist      0.00      0.00      0.02         0.00          0.02
# 3           Zoo Games      0.04      0.00      0.00         0.00          0.04
# 4         D3Publisher      0.12      0.09      0.00         0.04          0.25

# %%
# 시각화
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.Genre.value_counts()
# Out:
# Action          3308
# Sports          2347
# Misc            1737
# Role-Playing    1491
# Shooting        1310
# Adventure       1291
# Racing          1249
# Platform         885
# Simulation       868
# Fighting         848
# Strategy         682
# Puzzle           582
# Name: Genre, dtype: int64

# %%
# 시각화 1. 장르
# 1-1. 전체적인 장르 선호도 막대그래프
genre_sales = df[['Genre', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']]
genre_sales.columns = ['장르', '북미 판매량', '유럽 판매량', '일본 판매량', '그외 판매량', '전세계 판매량']
gs_grouped = genre_sales.groupby(['장르']).sum()
gs_grouped # 12개 장르를 기준으로 각 지역의 판매량 확인
# Out:
#               북미 판매량  유럽 판매량  일본 판매량  그외 판매량  전세계 판매량
# 장르
# Action        874.89  522.19  157.93  186.45  1741.46
# Adventure     107.48   65.67   53.76   17.17   244.08
# Fighting      223.59  101.32   87.35   36.68   448.94
# Misc          410.28  215.98  108.20   74.76   809.22
# Platform      446.96  201.62  130.77   51.58   830.93
# Puzzle        123.64   50.73   56.92   12.54   243.83
# Racing        359.44  238.39   56.69   77.27   731.79
# Role-Playing  328.63  189.38  352.57   60.76   931.34
# Shooting      582.60  313.27   38.28  102.69  1036.84
# Simulation    183.31  113.38   63.72   31.52   391.93
# Sports        683.38  376.85  135.37  134.97  1330.57
# Strategy       68.75   45.35   49.46   11.36   174.92

# %%
gs_grouped_table = gs_grouped.reset_index()
gs_grouped_table.head()
# Out:
#           장르  북미 판매량  유럽 판매량  일본 판매량  그외 판매량  전세계 판매량
# 0     Action  874.89  522.19  157.93  186.45  1741.46
# 1  Adventure  107.48   65.67   53.76   17.17   244.08
# 2   Fighting  223.59  101.32   87.35   36.68   448.94
# 3       Misc  410.28  215.98  108.20   74.76   809.22
# 4   Platform  446.96  201.62  130.77   51.58   830.93

# %%
gs_melted = pd.melt(gs_grouped_table, id_vars = ['장르'], value_vars = gs_grouped_table.columns[1:], var_name = '판매국가', value_name = '판매량')
gs_melted.head()
# Out:
#           장르    판매국가     판매량
# 0     Action  북미 판매량  874.89
# 1  Adventure  북미 판매량  107.48
# 2   Fighting  북미 판매량  223.59
# 3       Misc  북미 판매량  410.28
# 4   Platform  북미 판매량  446.96

# %%
gs_melted[-12:] # 전세계 장르 인기순위: Action > Sports > Shooting > Role-Playing
# Out:
#               장르     판매국가      판매량
# 48        Action  전세계 판매량  1741.46
# 49     Adventure  전세계 판매량   244.08
# 50      Fighting  전세계 판매량   448.94
# 51          Misc  전세계 판매량   809.22
# 52      Platform  전세계 판매량   830.93
# 53        Puzzle  전세계 판매량   243.83
# 54        Racing  전세계 판매량   731.79
# 55  Role-Playing  전세계 판매량   931.34
# 56      Shooting  전세계 판매량  1036.84
# 57    Simulation  전세계 판매량   391.93
# 58        Sports  전세계 판매량  1330.57
# 59      Strategy  전세계 판매량   174.92

# %%
# matplotlib 한글 폰트 깨짐 현상 해결 1
import matplotlib.font_manager as fm

font_list = fm.findSystemFonts(fontpaths = None, fontext = 'ttf')
# matplotlib 한글 폰트 깨짐 현상 해결 2 - 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = 'C:\\Windows\\Fonts\\malgun.ttf'
font = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family = font)

# %%
plt.figure(figsize=(16, 10))
sns.barplot(data = gs_melted, x = '장르', y = '판매량', hue = '판매국가')
plt.title('국가별 장르 선호도', loc='center', fontsize=24, pad = 10)
plt.legend(fontsize=15)
plt.show()

# 북미: Action > Sports > Shooting
# 유럽: Action > Sports > Shooting
# 일본: Role-Playing > Action > Platform
# 그외: Action > Sports > Shooting
# 전세계: Action > Sports > Shooting

# 일본을 제외한 국가들 전반에서 장르 선호도는 Action > Sports > Shooting 순으로 나타났다.

# %%
# 시각화 1. Genre 장르
# 1-2. 전체적인 장르 선호도 히트맵
plt.figure(figsize=(16, 10))

a = sns.heatmap(gs_grouped, annot=True, fmt = '.2f', cmap="YlGnBu")
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
a.set_ylabel('', fontsize=13)
plt.show()

# 1-1 히스토그램에서 확인한 바와 같이,
# 일본을 제외한 국가들에서 장르 선호도는 Action > Sports > Shooting 순이고
# 북미, 유럽 지역의 경우 그 양상이 유사하게 나타났다.
# 전 세계적으로는 Action, Sports 장르에 대한 선호가 매우 뚜렷한 편
# 유의사항: 히트맵에서는 아무래도 전세계 판매량 수치가 두드러지게 높아지므로, 개별 지역에 비해 색상 역시 두드러지게 나타난다는 점에 유의)

# %%
# 1-3. 장르 선호도 국가별 TOP 3
sales_column_list = gs_grouped_table.columns[1:]

def genre_top3(df, sales_column_list):
    df_new = df.loc[:,['장르', sales_column_list]].sort_values(by = sales_column_list, ascending = False).reset_index(drop = True).head(3)
    df_new.columns = ['장르', '판매량']
    return df_new

# %%
genre_top3_na = genre_top3(gs_grouped_table, '북미 판매량')
genre_top3_eu = genre_top3(gs_grouped_table, '유럽 판매량')
genre_top3_jp = genre_top3(gs_grouped_table, '일본 판매량')
genre_top3_other = genre_top3(gs_grouped_table, '그외 판매량')
genre_top3_global = genre_top3(gs_grouped_table, '전세계 판매량')

genre_top3_na # 북미 판매량 top3 확인
# Out:
#          장르     판매량
# 0    Action  874.89
# 1    Sports  683.38
# 2  Shooting  582.60

# %%
genre_top3_list = [genre_top3_na, genre_top3_eu, genre_top3_jp, genre_top3_other, genre_top3_global]
genre_top3_list
# Out:
# [         장르     판매량
#  0    Action  874.89
#  1    Sports  683.38
#  2  Shooting  582.60,
#           장르     판매량
#  0    Action  522.19
#  1    Sports  376.85
#  2  Shooting  313.27,
#               장르     판매량
#  0  Role-Playing  352.57
#  1        Action  157.93
#  2        Sports  135.37,
#           장르     판매량
#  0    Action  186.45
#  1    Sports  134.97
#  2  Shooting  102.69,
#           장르      판매량
#  0    Action  1741.46
#  1    Sports  1330.57
#  2  Shooting  1036.84]

# %%
sales_column_list
# Out:
# Index(['북미 판매량', '유럽 판매량', '일본 판매량', '그외 판매량', '전세계 판매량'], dtype='object')

# %%
fig, axes = plt.subplots(figsize = (35, 10), nrows = 1, ncols = 5)
for col, i, data in zip(sales_column_list, range(len(sales_column_list)), genre_top3_list):
    axes[i].set_title(col + ' ' + 'TOP 3', fontsize = 24, pad = 10)
    sns.barplot(x = '장르', y = '판매량', data = data, ax = axes[i])
    axes[i].tick_params(axis = 'both', labelsize = 16)
    axes[i].set_xlabel('장르', fontsize = 16)
    axes[i].set_ylabel('판매량', fontsize = 16)
plt.show()

# %%
# 1-3-1. 지역별 장르 선호도 TOP 5

# sales_column_list = gs_grouped_table.columns[1:]

def genre_top5(df, sales_column_list):
    df_new_g5 = df.loc[:,['장르', sales_column_list]].sort_values(by = sales_column_list, ascending = False).reset_index(drop = True).head(5)
    df_new_g5.columns = ['장르', '판매량']
    return df_new_g5

genre_top5_na = genre_top5(gs_grouped_table, '북미 판매량')
genre_top5_eu = genre_top5(gs_grouped_table, '유럽 판매량')
genre_top5_jp = genre_top5(gs_grouped_table, '일본 판매량')
genre_top5_other = genre_top5(gs_grouped_table, '그외 판매량')
genre_top5_global = genre_top5(gs_grouped_table, '전세계 판매량')
# genre_top5_na # 북미 판매량 top3 확인

genre_top5_list = [genre_top5_na, genre_top5_eu, genre_top5_jp, genre_top5_other, genre_top5_global]
genre_top5_list

fig, axes = plt.subplots(1, 5, figsize = (25, 8))
plt.subplots_adjust(wspace = 0.2) # subplots간의 너비 간격 조절

# 각 subplot에 pie plot 그리기
explode = (0.1, 0.1, 0.1, 0, 0) # 퍼짐 정도 조절
for i in range(len(sales_column_list)):
	ax = axes[i] # subplot 선택
	wedges, texts, autotexts = ax.pie(genre_top5_list[i].판매량, explode = explode, labels = genre_top5_list[i].장르,
	                                  autopct = '%.1f%%', pctdistance = 0.85,
	                                  shadow = False, startangle = 60)
	for w in wedges: # 조각 설정
		w.set_linewidth(0)
		w.set_edgecolor('w')
		
	for t in texts: # label 설정
		t.set_color('k')
		t.set_fontsize(18)
		
	for a in autotexts: # 퍼센티지 설정
		a.set_color('black')
		a.set_fontsize(14)
    
	centre_circle = plt.Circle((0,0), 0.7, color='black', fc='white', linewidth=0) # 파이차트를 도넛차트로 보이게 하는 trick
	ax.add_artist(centre_circle)
	axes[i].set_title(sales_column_list[i] + ' ' + 'TOP 5', fontsize = 24, pad = 2)
	ax.axis('equal')

# %%
exp = [0.1, 0, 0, 0, 0] # 퍼짐 정도 조절
# wed = {"width": 0.4}
plt.pie(genre_top5_na.판매량, labels = genre_top5_na.장르, autopct='%1.1f%%', pctdistance=0.85, startangle = 90, explode = exp, shadow = True)
plt.show()

# %%
genre_top5_list[0].장르
# Out:
# 0      Action
# 1      Sports
# 2    Shooting
# 3    Platform
# 4        Misc
# Name: 장르, dtype: object

# %%
sales_column_list
# Out:
# Index(['북미 판매량', '유럽 판매량', '일본 판매량', '그외 판매량', '전세계 판매량'], dtype='object')

# %%
# 1-4. 게임 출시량으로 보는 연도별 장르 트렌드

df.head()
# Out:
#                                              Name Platform  Year      Genre  \
# 0                    Candace Kane's Candy Factory       DS  2008     Action
# 1                                  The Munchables      Wii  2009     Action
# 2  Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010  Adventure
# 3                Deal or No Deal: Special Edition       DS  2010       Misc
# 4       Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010   Platform
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0           Destineer      0.04      0.00      0.00         0.00          0.04
# 1  Namco Bandai Games      0.17      0.00      0.00         0.01          0.18
# 2           Alchemist      0.00      0.00      0.02         0.00          0.02
# 3           Zoo Games      0.04      0.00      0.00         0.00          0.04
# 4         D3Publisher      0.12      0.09      0.00         0.04          0.25

# %%
# 1-4. 연도별 최고 출고량으로 보는 게임 장르 트렌드
df_yr_genre = df.groupby(['Year', 'Genre']).size().reset_index(name = 'count') # 연도별 각 장르 출시 개수 확인
df_yr_genre
# Out:
#      Year       Genre  count
# 0    1977      Action      2
# 1    1977      Racing      1
# 2    1977    Shooting      1
# 3    1978      Action      1
# 4    1978      Puzzle      2
# ..    ...         ...    ...
# 399  2018    Strategy      1
# 400  2019      Racing      2
# 401  2020    Shooting      1
# 402  2020  Simulation      1
# 403  2021      Racing      3
#
# [404 rows x 3 columns]

# %%
df_yg_max = df_yr_genre.groupby(['Year'])['count'].transform(max) == df_yr_genre['count'] # 연도별 최대 출시 개수 저장
year_max_genre = df_yr_genre[df_yg_max].reset_index(drop = True)
year_max_genre # 연도별 최대 수 출시 장르와 개수 확인
# 확인 결과 연도별 복수 장르가 존재하기도 하며 (예. 1984년) 이 경우 임의로 마지막 장르만 남기고 중복치 제거 진행해주도록 함
# Out:
#     Year         Genre  count
# 0   1977        Action      2
# 1   1978        Puzzle      2
# 2   1980          Misc      4
# 3   1981        Action     25
# 4   1982        Action     18
# 5   1983        Action      7
# 6   1984        Puzzle      3
# 7   1984        Racing      3
# 8   1984      Shooting      3
# 9   1985      Platform      4
# 10  1985        Puzzle      4
# 11  1986        Action      6
# 12  1986      Platform      6
# 13  1987        Sports      4
# 14  1988      Platform      4
# 15  1989        Puzzle      5
# 16  1990        Action      3
# 17  1990      Platform      3
# 18  1990        Sports      3
# 19  1991        Sports      7
# 20  1992      Fighting      7
# 21  1993      Fighting     11
# 22  1993      Platform     11
# 23  1994      Fighting     22
# 24  1994        Sports     22
# 25  1995      Fighting     29
# 26  1995      Shooting     29
# 27  1995        Sports     29
# 28  1996        Sports     52
# 29  1997        Sports     47
# 30  1998        Sports     71
# 31  1999        Sports     62
# 32  2000        Sports     81
# 33  2001        Sports     98
# 34  2002        Sports    194
# 35  2003        Action    147
# 36  2004        Action    127
# 37  2005        Action    196
# 38  2006        Action    186
# 39  2007        Action    214
# 40  2008        Action    228
# 41  2009        Action    273
# 42  2010        Action    228
# 43  2011        Action    255
# 44  2012        Action    264
# 45  2013        Action    151
# 46  2014        Action    187
# 47  2015        Action    254
# 48  2016        Action    119
# 49  2017  Role-Playing      2
# 50  2018      Shooting      1
# 51  2018      Strategy      1
# 52  2019        Racing      2
# 53  2020      Shooting      1
# 54  2020    Simulation      1
# 55  2021        Racing      3

# %%
year_max_genre = year_max_genre.drop_duplicates(subset = ['Year', 'count'], keep = 'last').reset_index(drop = True) # 중복치 제거, 마지막 데이터만 남겨줌
year_max_genre.columns = ['년도', '장르', '출시량']
year_max_genre[:15]
# Out:
#       년도        장르  출시량
# 0   1977    Action    2
# 1   1978    Puzzle    2
# 2   1980      Misc    4
# 3   1981    Action   25
# 4   1982    Action   18
# 5   1983    Action    7
# 6   1984  Shooting    3
# 7   1985    Puzzle    4
# 8   1986  Platform    6
# 9   1987    Sports    4
# 10  1988  Platform    4
# 11  1989    Puzzle    5
# 12  1990    Sports    3
# 13  1991    Sports    7
# 14  1992  Fighting    7

# %%
genre = year_max_genre['장르'].values

# %%
# matplotlib 한글 폰트 깨짐 현상 해결 1
import matplotlib.font_manager as fm

font_list = fm.findSystemFonts(fontpaths = None, fontext = 'ttf')
# matplotlib 한글 폰트 깨짐 현상 해결 2 - 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = 'C:\\Windows\\Fonts\\malgun.ttf'
font = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family = font)

# %%
plt.figure(figsize = (30, 15))
ax = sns.barplot(x = '년도', y = '출시량', data = year_max_genre)

idx = 0
for value in year_max_genre['출시량']:
    ax.text(x = idx, y = value + 5, s = str(genre[idx] + '--' + ' ' + str(value)), color = 'black', size = 14, rotation = 90, ha = 'center')
    idx += 1
plt.xticks(rotation = 90, fontsize = 14)
plt.yticks(rotation = 90, fontsize = 14)
plt.xlabel('년도', fontsize = 20)
plt.ylabel('출시량', fontsize = 20)
ax.set_title('연도별 최고 출고량으로 보는 게임 장르 트렌드', fontsize = 24, loc = 'left', pad = 20)
# 2000년대 초반부터 2010년 중반에 이르기까지 Action이 최근의 게임장르 트렌드였음을 확인할 수 있다.
# (단, 2010년대 중반부터 2022년 현재에 이르기까지 비교적 더 최근의 데이터 부재로 설명력 없다고 할 수도)
# Out:
# Text(0.0, 1.0, '연도별 최고 출고량으로 보는 게임 장르 트렌드')

# %%
# 1-5. 연도별 최고 판매량으로 보는 게임 장르 트렌드
df_yr_sales = df.groupby(['Year', 'Genre'])['Global_Sales'].sum().reset_index()
df_yr_sales.head(15)
# df_yr_genre = df.groupby(['Year', 'Genre']).size().reset_index(name = 'count') # 연도별 각 장르 출시 개수 확인
# Out:
#     Year      Genre  Global_Sales
# 0   1977     Action          1.56
# 1   1977     Racing          0.27
# 2   1977   Shooting          0.98
# 3   1978     Action          0.27
# 4   1978     Puzzle          0.81
# 5   1978   Shooting          2.53
# 6   1978     Sports          0.15
# 7   1980     Action          1.24
# 8   1980  Adventure          1.30
# 9   1980   Fighting          0.77
# 10  1980       Misc          2.70
# 11  1980     Racing          0.32
# 12  1980   Shooting          7.07
# 13  1980     Sports          1.02
# 14  1981     Action         14.79

# %%
year_max_sales = df_yr_sales.groupby(['Year'])['Global_Sales'].transform(max) == df_yr_sales['Global_Sales']
year_max_sales = df_yr_sales[year_max_sales].reset_index(drop = True)
year_max_sales.columns = ['년도', '장르', '전세계 판매량']
year_max_sales.head(10)
# df_yg_max = df_yr_genre.groupby(['Year'])['count'].transform(max) == df_yr_genre['count'] # 연도별 최대 출시 개수 저장
# year_max_genre = df_yr_genre[df_yg_max].reset_index(drop = True)
# year_max_genre # 연도별 최대 수 출시 장르와 개수 확인

# 아래 내용 검토할 것
# # 년도별 최고 판매량 기록한 장르 데이터프레임 만들기
# year_max_sales = df.groupby(['Year', 'Genre'])['Global_Sales'].sum().reset_index()
# condition = year_max_sales['Global_Sales'] == year_max_sales.groupby(['Year'])['Global_Sales'].transform(max)
# year_max_sales = year_max_sales[condition]
# year_max_sales.columns = ['년도', '장르', '전세계 판매량']
# year_max_sales[:5]
# Out:
#      년도        장르  전세계 판매량
# 0  1977    Action     1.56
# 1  1978  Shooting     2.53
# 2  1980  Shooting     7.07
# 3  1981    Action    14.79
# 4  1982    Puzzle    10.04
# 5  1983  Platform     6.93
# 6  1984  Shooting    31.10
# 7  1985  Platform    43.17
# 8  1986    Action    13.74
# 9  1987  Fighting     5.42

# %%
genre = year_max_sales['장르'].values

plt.figure(figsize=(30, 15))
ax = sns.barplot(x='년도', y='전세계 판매량', data=year_max_sales)
idx = 0
for value in year_max_sales['전세계 판매량']:
    ax.text(x = idx, y = value + 5, s = str(genre[idx] + '--' + ' ' + str(round(value, 2))),
            color='black', size=14, rotation=90, ha='center')
    idx += 1
ax.set_title('연도별 최고 판매량으로 보는 게임 장르 트렌드', fontsize = 24, loc = 'left', pad = 20)
plt.xticks(rotation=90, fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('년도', fontsize=20)
plt.ylabel('전세계 판매량', fontsize=20)
plt.show()
# 2000년대 초반~2010년대 중반까지 출시량으로 본 장르 트렌드에서와 마찬가지로 Action 장르가 동기간 높은 판매량을 보였다.
# 달리 말해서 Action 장르가 게임 유저들의 가장 큰 선택을 받았다. *선호가 높다

# %%
# 추가 고민할 분석 이슈
# 1. 지역별 판매량 비중 (전세계 판매량 대비)

# %%
# 시각화 2. 플랫폼 Platform
# 2-1. 플랫폼별 판매량 막대그래프

pf_sales = df[['Platform', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']]
pf_sales.columns = ['플랫폼', '북미 판매량', '유럽 판매량', '일본 판매량', '그외 판매량', '전세계 판매량']
ps_grouped = pf_sales.groupby(['플랫폼']).sum()
ps_grouped
# Out:
#       북미 판매량  유럽 판매량  일본 판매량  그외 판매량  전세계 판매량
# 플랫폼
# 2600   90.60    5.47    0.00    0.91    96.98
# 3DO     0.00    0.00    0.10    0.00     0.10
# 3DS    78.87   58.52   97.35   12.63   247.37
# DC      5.43    1.69    8.56    0.27    15.95
# DS    390.71  194.65  175.57   60.53   821.46
# GB    114.32   47.82   85.12    8.20   255.46
# GBA   187.54   75.25   47.33    7.73   317.85
# GC    133.46   38.71   21.58    5.18   198.93
# GEN    19.27    5.52    2.67    0.89    28.35
# GG      0.00    0.00    0.04    0.00     0.04
# N64   139.02   41.06   34.22    4.38   218.68
# NES   125.94   21.15   98.65    5.31   251.05
# NG      0.00    0.00    1.44    0.00     1.44
# PC     93.28  139.68    0.17   24.86   257.99
# PCFX    0.00    0.00    0.03    0.00     0.03
# PS    336.51  213.60  139.82   40.91   730.84
# PS2   583.84  339.29  139.20  193.44  1255.77
# PS3   392.26  343.71   79.99  141.93   957.89
# PS4    96.80  123.70   14.30   43.36   278.16
# PSP   108.99   68.25   76.79   42.19   296.22
# PSV    16.20   16.33   20.96    8.45    61.94
# SAT     0.72    0.54   32.26    0.07    33.59
# SCD     1.00    0.36    0.45    0.05     1.86
# SNES   61.23   19.04  116.55    3.22   200.04
# TG16    0.00    0.00    0.16    0.00     0.16
# WS      0.00    0.00    1.42    0.00     1.42
# Wii   507.71  268.38   69.35   80.61   926.05
# WiiU   38.32   24.23   12.79    6.45    81.79
# X360  601.05  280.58   12.43   85.54   979.60
# XB    186.69   60.95    1.38    8.72   257.74
# XOne   83.19   45.65    0.34   11.92   141.10

# %%
ps_grouped_table = ps_grouped.reset_index()
ps_grouped_table.head()
# Out:
#     플랫폼  북미 판매량  유럽 판매량  일본 판매량  그외 판매량  전세계 판매량
# 0  2600   90.60    5.47    0.00    0.91    96.98
# 1   3DO    0.00    0.00    0.10    0.00     0.10
# 2   3DS   78.87   58.52   97.35   12.63   247.37
# 3    DC    5.43    1.69    8.56    0.27    15.95
# 4    DS  390.71  194.65  175.57   60.53   821.46

# %%
ps_melted = pd.melt(ps_grouped_table, id_vars = ['플랫폼'], value_vars = ps_grouped_table.columns[1:], var_name = '판매국가', value_name = '판매량')
ps_melted.head()
# Out:
#     플랫폼    판매국가     판매량
# 0  2600  북미 판매량   90.60
# 1   3DO  북미 판매량    0.00
# 2   3DS  북미 판매량   78.87
# 3    DC  북미 판매량    5.43
# 4    DS  북미 판매량  390.71

# %%
ps_melted[-31:].sort_values(by = '판매량', ascending = False) 
# 전세계 플랫폼 인기순위: PS2 > X360 > PS3 > Wii
# Out:
#       플랫폼     판매국가      판매량
# 140   PS2  전세계 판매량  1255.77
# 152  X360  전세계 판매량   979.60
# 141   PS3  전세계 판매량   957.89
# 150   Wii  전세계 판매량   926.05
# 128    DS  전세계 판매량   821.46
# 139    PS  전세계 판매량   730.84
# 130   GBA  전세계 판매량   317.85
# 143   PSP  전세계 판매량   296.22
# 142   PS4  전세계 판매량   278.16
# 137    PC  전세계 판매량   257.99
# 153    XB  전세계 판매량   257.74
# 129    GB  전세계 판매량   255.46
# 135   NES  전세계 판매량   251.05
# 126   3DS  전세계 판매량   247.37
# 134   N64  전세계 판매량   218.68
# 147  SNES  전세계 판매량   200.04
# 131    GC  전세계 판매량   198.93
# 154  XOne  전세계 판매량   141.10
# 124  2600  전세계 판매량    96.98
# 151  WiiU  전세계 판매량    81.79
# 144   PSV  전세계 판매량    61.94
# 145   SAT  전세계 판매량    33.59
# 132   GEN  전세계 판매량    28.35
# 127    DC  전세계 판매량    15.95
# 146   SCD  전세계 판매량     1.86
# 136    NG  전세계 판매량     1.44
# 149    WS  전세계 판매량     1.42
# 148  TG16  전세계 판매량     0.16
# 125   3DO  전세계 판매량     0.10
# 133    GG  전세계 판매량     0.04
# 138  PCFX  전세계 판매량     0.03

# %%
# matplotlib 한글 폰트 깨짐 현상 해결 1
import matplotlib.font_manager as fm

font_list = fm.findSystemFonts(fontpaths = None, fontext = 'ttf')
# matplotlib 한글 폰트 깨짐 현상 해결 2 - 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = 'C:\\Windows\\Fonts\\malgun.ttf'
font = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family = font)

# %%
plt.figure(figsize=(16, 10))
sns.barplot(data = ps_melted, x = '플랫폼', y = '판매량', hue = '판매국가')
plt.title('플랫폼별 판매량', loc='center', fontsize=24, pad = 10)
plt.legend(fontsize=15)
plt.show()

# %%
# 2-2. 지역별 최고 판매량 플랫폼 TOP 3
sales_column_list_p = ps_grouped_table.columns[1:]

def pf_top3(df, sales_column_list_p):
    df_new_p = df.loc[:,['플랫폼', sales_column_list_p]].sort_values(by = sales_column_list_p, ascending = False).reset_index(drop = True).head(3)
    df_new_p.columns = ['플랫폼', '판매량']
    return df_new_p

pf_top3_na = pf_top3(ps_grouped_table, '북미 판매량')
pf_top3_eu = pf_top3(ps_grouped_table, '유럽 판매량')
pf_top3_jp = pf_top3(ps_grouped_table, '일본 판매량')
pf_top3_other = pf_top3(ps_grouped_table, '그외 판매량')
pf_top3_global = pf_top3(ps_grouped_table, '전세계 판매량')
pf_top3_na # 북미 판매량 top3 플랫폼 확인
# Out:
#     플랫폼     판매량
# 0  X360  601.05
# 1   PS2  583.84
# 2   Wii  507.71

# %%
pf_top3_list = [pf_top3_na, pf_top3_eu, pf_top3_jp, pf_top3_other, pf_top3_global]
pf_top3_list
# Out:
# [    플랫폼     판매량
#  0  X360  601.05
#  1   PS2  583.84
#  2   Wii  507.71,
#      플랫폼     판매량
#  0   PS3  343.71
#  1   PS2  339.29
#  2  X360  280.58,
#     플랫폼     판매량
#  0   DS  175.57
#  1   PS  139.82
#  2  PS2  139.20,
#      플랫폼     판매량
#  0   PS2  193.44
#  1   PS3  141.93
#  2  X360   85.54,
#      플랫폼      판매량
#  0   PS2  1255.77
#  1  X360   979.60
#  2   PS3   957.89]

# %%
fig, axes = plt.subplots(figsize = (35, 10), nrows = 1, ncols = 5)
for col, i, data in zip(sales_column_list_p, range(len(sales_column_list_p)), pf_top3_list):
    axes[i].set_title(col + ' ' + 'TOP 3', fontsize = 24, pad = 10)
    sns.barplot(x = '플랫폼', y = '판매량', data = data, ax = axes[i])
    axes[i].tick_params(axis = 'both', labelsize = 16)
    axes[i].set_xlabel('플랫폼', fontsize = 16)
    axes[i].set_ylabel('판매량', fontsize = 16)
plt.show()

# 전반적으로 플레이스테이션에 대한 선호가 높은 편

# %%
# 2-2. 지역별 최고 판매량 플랫폼 TOP 3 (수정)

# sales_column_list_p = ['북미 판매량', '유럽 판매량', '일본 판매량', '그외 판매량', '전세계 판매량']

ps_grouped_table_na = ps_grouped.reset_index().sort_values(by=['북미 판매량'], ascending=False)
ps_grouped_table_eu = ps_grouped.reset_index().sort_values(by=['유럽 판매량'], ascending=False)
ps_grouped_table_jp = ps_grouped.reset_index().sort_values(by=['일본 판매량'], ascending=False)
ps_grouped_table_other = ps_grouped.reset_index().sort_values(by=['그외 판매량'], ascending=False)
ps_grouped_table_global = ps_grouped.reset_index().sort_values(by=['전세계 판매량'], ascending=False)

def pf_top3(df, sales_column_list_p):
    df_new_p = df.loc[:,['플랫폼', sales_column_list_p]].sort_values(by = sales_column_list_p, ascending = False).reset_index(drop = True).head(3)
    df_new_p.columns = ['플랫폼', '판매량']
    return df_new_p

pf_top3_na = pf_top3(ps_grouped_table_na, '북미 판매량')
pf_top3_eu = pf_top3(ps_grouped_table_eu, '유럽 판매량')
pf_top3_jp = pf_top3(ps_grouped_table_jp, '일본 판매량')
pf_top3_other = pf_top3(ps_grouped_table_other, '그외 판매량')
pf_top3_global = pf_top3(ps_grouped_table_global, '전세계 판매량')
# pf_top3_na # 북미 판매량 top3 플랫폼 확인

pf_top3_list = [pf_top3_na, pf_top3_eu, pf_top3_jp, pf_top3_other, pf_top3_global]
pf_top3_list

fig, axes = plt.subplots(figsize = (35, 10), nrows = 1, ncols = 5)
for col, i, data in zip(sales_column_list_p, range(len(sales_column_list_p)), pf_top3_list):
    axes[i].set_title(col + ' ' + 'TOP 3', fontsize = 24, pad = 10)
    sns.barplot(x = '플랫폼', y = '판매량', data = data, ax = axes[i])
    axes[i].tick_params(axis = 'both', labelsize = 16)
    axes[i].set_xlabel('플랫폼', fontsize = 16)
    axes[i].set_ylabel('판매량', fontsize = 16)
plt.show()

# 전반적으로 플레이스테이션에 대한 선호가 높은 편

# %%
ps_grouped_table_jp.head(6)
# Out:
#      플랫폼  북미 판매량  유럽 판매량  일본 판매량  그외 판매량  전세계 판매량
# 4     DS  390.71  194.65  175.57   60.53   821.46
# 15    PS  336.51  213.60  139.82   40.91   730.84
# 16   PS2  583.84  339.29  139.20  193.44  1255.77
# 23  SNES   61.23   19.04  116.55    3.22   200.04
# 11   NES  125.94   21.15   98.65    5.31   251.05
# 2    3DS   78.87   58.52   97.35   12.63   247.37

# %%
ps_grouped_table_global.head(6)
# Out:
#      플랫폼  북미 판매량  유럽 판매량  일본 판매량  그외 판매량  전세계 판매량
# 16   PS2  583.84  339.29  139.20  193.44  1255.77
# 28  X360  601.05  280.58   12.43   85.54   979.60
# 17   PS3  392.26  343.71   79.99  141.93   957.89
# 26   Wii  507.71  268.38   69.35   80.61   926.05
# 4     DS  390.71  194.65  175.57   60.53   821.46
# 15    PS  336.51  213.60  139.82   40.91   730.84

# %%
# 2-2. 지역별 최고 판매량 플랫폼 TOP 5 파이 차트

sales_column_list_p = ps_grouped_table.columns[1:]

def pf_top5(df, sales_column_list_p):
    df_new_p5 = df.loc[:,['플랫폼', sales_column_list_p]].sort_values(by = sales_column_list_p, ascending = False).reset_index(drop = True).head(5)
    df_new_p5.columns = ['플랫폼', '판매량']
    return df_new_p5

pf_top5_na = pf_top5(ps_grouped_table, '북미 판매량')
pf_top5_eu = pf_top5(ps_grouped_table, '유럽 판매량')
pf_top5_jp = pf_top5(ps_grouped_table, '일본 판매량')
pf_top5_other = pf_top5(ps_grouped_table, '그외 판매량')
pf_top5_global = pf_top5(ps_grouped_table, '전세계 판매량')
# pf_top5_na # 북미 판매량 top3 플랫폼 확인

pf_top5_list = [pf_top5_na, pf_top5_eu, pf_top5_jp, pf_top5_other, pf_top5_global]
# pf_top5_list

# %%
ps_grouped_table.head(5)
# Out:
#     플랫폼  북미 판매량  유럽 판매량  일본 판매량  그외 판매량  전세계 판매량
# 0  2600   90.60    5.47    0.00    0.91    96.98
# 1   3DO    0.00    0.00    0.10    0.00     0.10
# 2   3DS   78.87   58.52   97.35   12.63   247.37
# 3    DC    5.43    1.69    8.56    0.27    15.95
# 4    DS  390.71  194.65  175.57   60.53   821.46

# %%
fig, axes = plt.subplots(1, 5, figsize = (25, 8))
plt.subplots_adjust(wspace = 0.2) # subplots간의 너비 간격 조절

# 각 subplot에 pie plot 그리기
explode = (0.1, 0.1, 0.1, 0, 0) # 퍼짐 정도 조절
for i in range(len(sales_column_list_p)):
	ax = axes[i] # subplot 선택
	wedges, texts, autotexts = ax.pie(pf_top5_list[i].판매량, explode = explode, labels = pf_top5_list[i].플랫폼,
	                                  autopct = '%.1f%%', pctdistance = 0.85,
	                                  shadow = False, startangle = 60)
	for w in wedges: # 조각 설정
		w.set_linewidth(0)
		w.set_edgecolor('w')
		
	for t in texts: # label 설정
		t.set_color('k')
		t.set_fontsize(18)
		
	for a in autotexts: # 퍼센티지 설정
		a.set_color('black')
		a.set_fontsize(14)
    
	centre_circle = plt.Circle((0,0), 0.7, color='black', fc='white', linewidth=0) # 파이차트를 도넛차트로 보이게 하는 trick
	ax.add_artist(centre_circle)
	axes[i].set_title(sales_column_list_p[i] + ' ' + 'TOP 5', fontsize = 24, pad = 2)
	ax.axis('equal')

# %%
# 2-2. 지역별 최고 판매량 플랫폼 TOP 5 파이 차트 (수정)

# sales_column_list_p = ['북미 판매량', '유럽 판매량', '일본 판매량', '그외 판매량', '전세계 판매량']

# ps_grouped_table_na = ps_grouped.reset_index().sort_values(by=['북미 판매량'], ascending=False)
# ps_grouped_table_eu = ps_grouped.reset_index().sort_values(by=['유럽 판매량'], ascending=False)
# ps_grouped_table_jp = ps_grouped.reset_index().sort_values(by=['일본 판매량'], ascending=False)
# ps_grouped_table_other = ps_grouped.reset_index().sort_values(by=['그외 판매량'], ascending=False)
# ps_grouped_table_global = ps_grouped.reset_index().sort_values(by=['전세계 판매량'], ascending=False)


def pf_top5(df, sales_column_list_p):
    df_new_p5 = df.loc[:,['플랫폼', sales_column_list_p]].sort_values(by = sales_column_list_p, ascending = False).reset_index(drop = True).head(5)
    df_new_p5.columns = ['플랫폼', '판매량']
    return df_new_p5

pf_top5_na = pf_top5(ps_grouped_table_na, '북미 판매량')
pf_top5_eu = pf_top5(ps_grouped_table_eu, '유럽 판매량')
pf_top5_jp = pf_top5(ps_grouped_table_jp, '일본 판매량')
pf_top5_other = pf_top5(ps_grouped_table_other, '그외 판매량')
pf_top5_global = pf_top5(ps_grouped_table_global, '전세계 판매량')
# pf_top5_na # 북미 판매량 top3 플랫폼 확인

pf_top5_list = [pf_top5_na, pf_top5_eu, pf_top5_jp, pf_top5_other, pf_top5_global]
# pf_top5_list

fig, axes = plt.subplots(1, 5, figsize = (25, 8))
plt.subplots_adjust(wspace = 0.2) # subplots간의 너비 간격 조절

# 각 subplot에 pie plot 그리기
explode = (0.1, 0.1, 0.1, 0, 0) # 퍼짐 정도 조절
for i in range(len(sales_column_list_p)):
	ax = axes[i] # subplot 선택
	wedges, texts, autotexts = ax.pie(pf_top5_list[i].판매량, explode = explode, labels = pf_top5_list[i].플랫폼,
	                                  autopct = '%.1f%%', pctdistance = 0.85,
	                                  shadow = False, startangle = 30)
	for w in wedges: # 조각 설정
		w.set_linewidth(0)
		w.set_edgecolor('w')
		
	for t in texts: # label 설정
		t.set_color('k')
		t.set_fontsize(12)
		
	for a in autotexts: # 퍼센티지 설정
		a.set_color('black')
		a.set_fontsize(14)
    
	centre_circle = plt.Circle((0,0), 0.7, color='black', fc='white', linewidth=0) # 파이차트를 도넛차트로 보이게 하는 trick
	ax.add_artist(centre_circle)
	axes[i].set_title(sales_column_list_p[i] + ' ' + 'TOP 5', fontsize = 24, pad = 2)
	ax.axis('equal')

# %%
ps_grouped_table_jp.head(5) # = ps_grouped.reset_index().sort_values(by=['일본 판매량'], ascending=False)
# Out:
#      플랫폼  북미 판매량  유럽 판매량  일본 판매량  그외 판매량  전세계 판매량
# 4     DS  390.71  194.65  175.57   60.53   821.46
# 15    PS  336.51  213.60  139.82   40.91   730.84
# 16   PS2  583.84  339.29  139.20  193.44  1255.77
# 23  SNES   61.23   19.04  116.55    3.22   200.04
# 11   NES  125.94   21.15   98.65    5.31   251.05

# %%
ps_grouped_table_global.head(5) # = ps_grouped.reset_index().sort_values(by=['전세계 판매량'], ascending=False)
# Out:
#      플랫폼  북미 판매량  유럽 판매량  일본 판매량  그외 판매량  전세계 판매량
# 16   PS2  583.84  339.29  139.20  193.44  1255.77
# 28  X360  601.05  280.58   12.43   85.54   979.60
# 17   PS3  392.26  343.71   79.99  141.93   957.89
# 26   Wii  507.71  268.38   69.35   80.61   926.05
# 4     DS  390.71  194.65  175.57   60.53   821.46

# %%
# 2-3. 연도별 가장 많은 게임을 출시한 플랫폼
df_yr_pf = df.groupby(['Year', 'Platform']).size().reset_index(name = 'count')
df_yr_pf.head(15) # df_yr_pf.shape: (260, 3)
# df_yr_genre = df.groupby(['Year', 'Genre']).size().reset_index(name = 'count') # 연도별 각 장르 출시 개수 확인
# Out:
#     Year Platform  count
# 0   1977     2600      4
# 1   1978     2600      5
# 2   1980     2600     14
# 3   1981     2600     46
# 4   1982     2600     37
# 5   1983     2600     11
# 6   1983      NES      6
# 7   1984     2600      1
# 8   1984      NES     13
# 9   1985     2600      1
# 10  1985       DS      1
# 11  1985      NES     11
# 12  1985       PC      1
# 13  1986     2600      2
# 14  1986      NES     19

# %%
year_max_pf = df_yr_pf.groupby(['Year'])['count'].transform(max) == df_yr_pf['count']
year_max_pf = df_yr_pf[year_max_pf].reset_index(drop = True)

# 아래 내용 검토할 것!
# # 가장 값이 큰 값만 뽑기
# condition = year_max_pf.groupby(['Year'])['count'].transform(max) == year_max_pf['count']
# year_max_pf = year_max_pf[condition].reset_index(drop=True)

year_max_pf = year_max_pf.drop_duplicates(subset = ['Year', 'count'], keep = 'last').reset_index(drop = True) # 중복치 제거, 마지막 데이터만 남겨줌
year_max_pf.columns = ['년도', '플랫폼', '출시량']
year_max_pf.head(30)
# df_yg_max = df_yr_genre.groupby(['Year'])['count'].transform(max) == df_yr_genre['count'] # 연도별 최대 출시 개수 저장
# year_max_genre = df_yr_genre[df_yg_max].reset_index(drop = True)
# year_max_genre # 연도별 최대 수 출시 장르와 개수 확인
# Out:
#       년도   플랫폼  출시량
# 0   1977  2600    4
# 1   1978  2600    5
# 2   1980  2600   14
# 3   1981  2600   46
# 4   1982  2600   37
# 5   1983  2600   11
# 6   1984   NES   13
# 7   1985   NES   11
# 8   1986   NES   19
# 9   1987   NES   10
# 10  1988   NES   11
# 11  1989    GB   10
# 12  1990   NES    8
# 13  1991  SNES   24
# 14  1992  SNES   21
# 15  1993  SNES   46
# 16  1994  SNES   53
# 17  1995    PS   99
# 18  1996    PS  164
# 19  1997    PS  188
# 20  1998    PS  250
# 21  1999    PS  201
# 22  2000    PS  161
# 23  2001   PS2  186
# 24  2002   PS2  292
# 25  2003   PS2  260
# 26  2004   PS2  263
# 27  2005   PS2  265
# 28  2006   PS2  264
# 29  2007    DS  382

# %%
year_max_pf[-10:] # 년도 중복 데이터 삭제 확인 가능 (예. 2021년)
# Out:
#       년도   플랫폼  출시량
# 34  2012   PS3  149
# 35  2013   PS3  128
# 36  2014   PS3  109
# 37  2015   PS4  137
# 38  2016   PS4  107
# 39  2017   PSV    2
# 40  2018    XB    1
# 41  2019    PC    1
# 42  2020    PC    1
# 43  2021  X360    1

# %%
platform = year_max_pf['플랫폼'].values

# %%
plt.figure(figsize=(30, 15))
ax = sns.barplot(x='년도', y='출시량', data=year_max_pf)
idx = 0
for value in year_max_pf['출시량']:
    ax.text(x = idx, y = value + 5, s = str(platform[idx] + '--' + ' ' + str(value)),
            color='black', size=14, rotation=90, ha='center')
    idx += 1
ax.set_title('연도별 가장 많은 게임을 출시한 플랫폼', fontsize = 24, loc = 'left', pad = 20)
plt.xticks(rotation=90, fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('년도', fontsize=20)
plt.ylabel('출시량', fontsize=20)
plt.show()
# 1990년대 중반부터 플레이스테이션이 꾸준히 높은 출시량을 기록 * = 시장 점유...?
# 2007~2010년까지 닌텐도 DS의 출시량이 두드러지게 높았음

# %%
# 2-4. 연도별 가장 많은 게임 판매량을 기록한 플랫폼

yr_pf_sales = df.groupby(['Year', 'Platform'])['Global_Sales'].sum().reset_index()
yr_pf_sales.head(15)
# df_yr_genre = df.groupby(['Year', 'Genre']).size().reset_index(name = 'count') # 연도별 각 장르 출시 개수 확인
# Out:
#     Year Platform  Global_Sales
# 0   1977     2600          2.81
# 1   1978     2600          3.76
# 2   1980     2600         14.42
# 3   1981     2600         35.68
# 4   1982     2600         29.35
# 5   1983     2600          5.84
# 6   1983      NES         10.96
# 7   1984     2600          0.27
# 8   1984      NES         50.08
# 9   1985     2600          0.45
# 10  1985       DS          0.02
# 11  1985      NES         53.44
# 12  1985       PC          0.04
# 13  1986     2600          0.67
# 14  1986      NES         36.41

# %%
# year_max_pf_sales = yr_pf_sales.groupby(['Year'])['Global_Sales'].transform(max) == df_yr_sales['Global_Sales']
# year_max_pf_sales = yr_pf_sales[year_max_pf_sales].reset_index(drop = True)

# 아래 내용 검토할 것! (위 내용 대체 가능할수도)

yr_pf_sales = df.groupby(['Year', 'Platform'])['Global_Sales'].sum().reset_index()
yr_pf_sales.head(15)

condition = yr_pf_sales['Global_Sales'] == yr_pf_sales.groupby(['Year'])['Global_Sales'].transform(max)
year_max_pf_sales = yr_pf_sales[condition]

year_max_pf_sales.columns = ['년도', '플랫폼', '전세계 판매량']
year_max_pf_sales.head(10)
# df_yg_max = df_yr_genre.groupby(['Year'])['count'].transform(max) == df_yr_genre['count'] # 연도별 최대 출시 개수 저장
# year_max_genre = df_yr_genre[df_yg_max].reset_index(drop = True)
# year_max_genre # 연도별 최대 수 출시 장르와 개수 확인
# Out:
#       년도   플랫폼  전세계 판매량
# 0   1977  2600     2.81
# 1   1978  2600     3.76
# 2   1980  2600    14.42
# 3   1981  2600    35.68
# 4   1982  2600    29.35
# 6   1983   NES    10.96
# 8   1984   NES    50.08
# 11  1985   NES    53.44
# 14  1986   NES    36.41
# 16  1987   NES    19.76

# %%
platform = year_max_pf_sales['플랫폼'].values

# %%
plt.figure(figsize=(30, 15))
ax = sns.barplot(x='년도', y='전세계 판매량', data=year_max_pf_sales)
idx = 0
for value in year_max_pf_sales['전세계 판매량']:
    ax.text(x = idx, y = value + 2, s = str(platform[idx] + '--' + ' ' + str(round(value, 2))),
            color = 'black', size = 14, rotation = 90, ha = 'center')
    idx += 1
ax.set_title('연도별 가장 많은 게임 판매량을 기록한 플랫폼', fontsize = 24, loc = 'left', pad = 20)
plt.xticks(rotation=90, fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('년도', fontsize=20)
plt.ylabel('전세계 판매량', fontsize=20)
plt.show()
# 출시량이 높았던 플레이스테이션이 꾸준히 높은 판매량을 기록하고 있음 (소비자 선호도 가장 높다)
# 2006~2009년까지 잠시 Wii의 인기가 높았지만 이후 플레이스테이션, XBOX의 후속작에 밀림

# %%
# 시각화 3. 게임회사 Publisher
# 3-1. 게임회사별 판매량

pub_sales = df[['Publisher', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']]
pub_sales.columns = ['게임회사명', '북미 판매량', '유럽 판매량', '일본 판매량', '그외 판매량', '전세계 판매량']
pubs_grouped = pub_sales.groupby(['게임회사명']).sum()
pubs_grouped
# Out:
#                               북미 판매량  유럽 판매량  일본 판매량  그외 판매량  전세계 판매량
# 게임회사명
# 10TACLE Studios                 0.07    0.04    0.00    0.00     0.11
# 1C Company                      0.01    0.07    0.00    0.02     0.10
# 20th Century Fox Video Games    1.82    0.10    0.00    0.01     1.93
# 2D Boy                          0.00    0.03    0.00    0.01     0.04
# 3DO                             6.48    3.04    0.00    0.63    10.15
# ...                              ...     ...     ...     ...      ...
# id Software                     0.02    0.00    0.00    0.00     0.02
# imageepoch Inc.                 0.00    0.00    0.04    0.00     0.04
# inXile Entertainment            0.02    0.06    0.00    0.01     0.09
# mixi, Inc                       0.00    0.00    0.86    0.00     0.86
# responDESIGN                    0.09    0.04    0.00    0.01     0.14
#
# [590 rows x 5 columns]

# %%
pubs_grouped.reset_index().sort_values(by = '북미 판매량', ascending = False).head(6)

pub1_top5_na[1]
def pub1_top5(df, sales_column_list_pub):
    df_new_pub1 = df.loc[:,['게임회사명', sales_column_list_pub]].sort_values(by = sales_column_list_pub, ascending = False).reset_index(drop = True).head(5)
    df_new_pub1.columns = ['게임회사명', '판매량']
    return df_new_pub1

pub1_top5_na = pub1_top5(pubs_grouped_table_na, '북미 판매량')

# %%
pub1_columns = ['북미 판매량', '유럽 판매량', '일본 판매량', '그외 판매량', '전세계 판매량']
pub1_values = [pub1_top5_na.판매량, pub1_top5_eu.판매량, pub1_top5_jp.판매량, pub1_top5_other.판매량, pub1_top5_global.판매량]

pub_sorted_df = pd.DataFrame(list(zip(pub1_top5_na.판매량, pub1_top5_eu.판매량, pub1_top5_jp.판매량, pub1_top5_other.판매량, pub1_top5_global.판매량)),
               columns = pub1_columns)
pub_sorted_df
# Out:
#    북미 판매량  유럽 판매량  일본 판매량  그외 판매량  전세계 판매량
# 0  817.28  418.90  455.77  129.77  1787.29
# 1  595.07  371.27  127.34   95.34  1110.15
# 2  429.70  215.53   91.40   80.47   727.11
# 3  265.89  187.97   74.10   75.34   608.43
# 4  253.43  163.32   68.13   55.24   474.51

# %%
pubs_grouped_table = pubs_grouped.reset_index().sort_values(by=['전세계 판매량'], ascending=False).head(6) 
# 데이터셋 내 전체 591개 게임회사 중 판매량 상위 6개 회사만 대상으로 시각화 진행
pubs_grouped_table # pubs_grouped_table.shape: (6, 6)
# Out:
#                            게임회사명  북미 판매량  유럽 판매량  일본 판매량  그외 판매량  전세계 판매량
# 368                     Nintendo  817.28  418.90  455.77   95.34  1787.29
# 140              Electronic Arts  595.07  371.27   14.04  129.77  1110.15
# 22                    Activision  429.70  215.53    6.54   75.34   727.11
# 466  Sony Computer Entertainment  265.89  187.97   74.10   80.47   608.43
# 536                      Ubisoft  253.43  163.32    7.50   50.26   474.51
# 504         Take-Two Interactive  220.49  118.14    5.83   55.24   399.70

# %%
pubs_grouped.reset_index().sort_values(by=['전세계 판매량'], ascending=False).head(15)
# Out:
#                                       게임회사명  북미 판매량  유럽 판매량  일본 판매량  그외 판매량  \
# 368                                Nintendo  817.28  418.90  455.77   95.34
# 140                         Electronic Arts  595.07  371.27   14.04  129.77
# 22                               Activision  429.70  215.53    6.54   75.34
# 466             Sony Computer Entertainment  265.89  187.97   74.10   80.47
# 536                                 Ubisoft  253.43  163.32    7.50   50.26
# 504                    Take-Two Interactive  220.49  118.14    5.83   55.24
# 498                                     THQ  210.47   95.80    5.01   32.55
# 284            Konami Digital Entertainment   92.16   69.69   91.40   30.31
# 456                                    Sega  109.40   82.00   57.03   24.52
# 356                      Namco Bandai Games   69.67   42.68  127.34   14.70
# 332                  Microsoft Game Studios  155.35   68.61    3.26   18.56
# 86                                   Capcom   78.59   39.22   68.13   14.84
# 54                                    Atari  110.14   27.20   10.71    9.04
# 561  Warner Bros. Interactive Entertainment   81.18   53.12    1.04   18.56
# 475                             Square Enix   48.65   32.82   49.88   13.89
#
#      전세계 판매량
# 368  1787.29
# 140  1110.15
# 22    727.11
# 466   608.43
# 536   474.51
# 504   399.70
# 498   343.83
# 284   283.56
# 456   272.95
# 356   254.39
# 332   245.78
# 86    200.78
# 54    157.09
# 561   153.90
# 475   145.24

# %%
pubs_melted = pd.melt(pubs_grouped_table, id_vars = ['게임회사명'], value_vars = pubs_grouped_table.columns[1:], var_name = '판매국가', value_name = '판매량')
pubs_melted.head()
# Out:
#                          게임회사명    판매국가     판매량
# 0                     Nintendo  북미 판매량  817.28
# 1              Electronic Arts  북미 판매량  595.07
# 2                   Activision  북미 판매량  429.70
# 3  Sony Computer Entertainment  북미 판매량  265.89
# 4                      Ubisoft  북미 판매량  253.43

# %%
pubs_melted[-6:].sort_values(by = '판매량', ascending = False)
# 전세계 게임회사 판매량 순위: Nintendo > Electronic Arts > Activision > Sony Computer Entertainment
# Out:
#                           게임회사명     판매국가      판매량
# 24                     Nintendo  전세계 판매량  1787.29
# 25              Electronic Arts  전세계 판매량  1110.15
# 26                   Activision  전세계 판매량   727.11
# 27  Sony Computer Entertainment  전세계 판매량   608.43
# 28                      Ubisoft  전세계 판매량   474.51
# 29         Take-Two Interactive  전세계 판매량   399.70

# %%
# matplotlib 한글 폰트 깨짐 현상 해결 1
import matplotlib.font_manager as fm

font_list = fm.findSystemFonts(fontpaths = None, fontext = 'ttf')
# matplotlib 한글 폰트 깨짐 현상 해결 2 - 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = 'C:\\Windows\\Fonts\\malgun.ttf'
font = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family = font)

# %%
# XX

plt.figure(figsize=(16, 10))
sns.barplot(data = pubs_melted, x = '게임회사명', y = '판매량', hue = '판매국가')
plt.title('게임회사별 판매량 (상위 6개)', loc='center', fontsize=24, pad = 10)
plt.legend(fontsize=15)
plt.show()

# 전세계 게임회사 판매량 순위: Nintendo > Electronic Arts > Activision > Sony Computer Entertainment
# 북미, 유럽의 경우 전세계 순위와 동일한 양상
# 일본의 경우 Nintendo, Sony Computer Entertainment 등 자국 회사 선호 뚜렷

# %%
df.head()
# Out:
#                                              Name Platform  Year      Genre  \
# 0                    Candace Kane's Candy Factory       DS  2008     Action
# 1                                  The Munchables      Wii  2009     Action
# 2  Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010  Adventure
# 3                Deal or No Deal: Special Edition       DS  2010       Misc
# 4       Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010   Platform
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0           Destineer      0.04      0.00      0.00         0.00          0.04
# 1  Namco Bandai Games      0.17      0.00      0.00         0.01          0.18
# 2           Alchemist      0.00      0.00      0.02         0.00          0.02
# 3           Zoo Games      0.04      0.00      0.00         0.00          0.04
# 4         D3Publisher      0.12      0.09      0.00         0.04          0.25

# %%
# 3-2. 연도별 가장 많은 게임을 출시한 게임회사

year_max_pubs = df.groupby(['Year', 'Publisher']).size().reset_index(name = 'count')
condition = year_max_pubs['count'] == year_max_pubs.groupby(['Year'])['count'].transform(max)
year_max_pubs = year_max_pubs[condition]
# 윗 두줄 의미??
year_max_pubs[:15] # year_max_pubs.shape: (49, 3)
# Out:
#     Year   Publisher  count
# 0   1977       Atari      4
# 1   1978       Atari      5
# 2   1980  Activision      7
# 3   1980       Atari      7
# 6   1981       Atari     11
# 21  1982       Atari     14
# 38  1983       Atari      6
# 39  1983    Nintendo      6
# 44  1984    Nintendo      9
# 50  1985    Nintendo      7
# 56  1986    Nintendo      6
# 58  1987       Atari      4
# 63  1987    Nintendo      4
# 70  1988    Nintendo      6
# 78  1989    Nintendo      9

# %%
year_max_pubs = year_max_pubs.drop_duplicates(subset = ['Year', 'count'], keep = 'last').reset_index(drop = True)
year_max_pubs.columns = ['년도', '게임회사명', '출시량']
publisher = year_max_pubs['게임회사명'].values

# %%
publisher = year_max_pubs['게임회사명'].values
publisher
# Out:
# array(['Atari', 'Atari', 'Atari', 'Atari', 'Atari', 'Nintendo',
#        'Nintendo', 'Nintendo', 'Nintendo', 'Nintendo', 'Nintendo',
#        'Nintendo', 'Nintendo', 'Nintendo', 'Nintendo', 'Nintendo', 'Sega',
#        'Sony Computer Entertainment', 'Sony Computer Entertainment',
#        'Sony Computer Entertainment', 'Sony Computer Entertainment',
#        'Konami Digital Entertainment', 'Sony Computer Entertainment',
#        'Electronic Arts', 'Electronic Arts', 'Electronic Arts',
#        'Electronic Arts', 'Electronic Arts', 'Electronic Arts',
#        'Electronic Arts', 'Electronic Arts', 'Activision', 'Activision',
#        'Ubisoft', 'Namco Bandai Games', 'Namco Bandai Games',
#        'Namco Bandai Games', 'Namco Bandai Games', 'Namco Bandai Games',
#        'Sega', 'Unknown', 'Codemasters', 'Ubisoft', 'Black Bean Games'],
#       dtype=object)

# %%
plt.figure(figsize=(30, 15))
ax = sns.barplot(x='년도', y='출시량', data=year_max_pubs)
idx = 0
for value in year_max_pubs['출시량']:
    ax.text(x = idx, y = value + 2, s = str(publisher[idx] + '--' + ' ' + str(value)),
            color = 'black', size = 14, rotation = 90, ha = 'center')
    idx += 1
ax.set_title('연도별 가장 많은 게임을 출시한 게임회사', fontsize = 24, loc = 'left', pad = 20)
plt.xticks(rotation=90, fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('년도', fontsize=20)
plt.ylabel('출시량', fontsize=20)
plt.show()
# 1990년대까지는 일본 회사들이 주축을 이루다가 2000년대에 들어서며 미국회사인 Electronic Arts 사의 부상
# 2012~2016년 사이 Namco Bandai Games 사가 가장 높은 출시량 기록

# %%
# 3-3. 연도별 가장 많은 게임 판매량을 기록한 게임회사

year_max_pubs_sales = df.groupby(['Year', 'Publisher'])['Global_Sales'].sum().reset_index(name = 'sales')
condition = year_max_pubs_sales['sales'] == year_max_pubs_sales.groupby(['Year'])['sales'].transform(max)
year_max_pubs_sales = year_max_pubs_sales[condition]
# 윗 두줄 의미??
year_max_pubs_sales.head(5)
# Out:
#     Year   Publisher  sales
# 0   1977       Atari   2.81
# 1   1978       Atari   3.76
# 3   1980       Atari  10.55
# 5   1981  Activision   8.49
# 21  1982       Atari  19.43

# %%
year_max_pubs_sales = year_max_pubs_sales.drop_duplicates(subset = ['Year', 'sales'], keep = 'last').reset_index(drop = True)
year_max_pubs_sales.columns = ['년도', '게임회사명', '판매량']

# %%
publisher = year_max_pubs_sales['게임회사명'].values

# %%
plt.figure(figsize=(30, 15))
ax = sns.barplot(x = '년도', y = '판매량', data = year_max_pubs_sales)
idx = 0
for value in year_max_pubs_sales['판매량']:
    ax.text(x = idx, y = value + 2, s = str(publisher[idx] + '--' + ' ' + str(round(value, 2))),
            color = 'black', size = 14, rotation = 90, ha = 'center')
    idx += 1
ax.set_title('연도별 가장 많은 게임 판매량을 기록한 게임회사', fontsize = 24, loc = 'left', pad = 20)
plt.xticks(rotation=90, fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('년도', fontsize=20)
plt.ylabel('판매량', fontsize=20)
plt.show()
# 1990년대 후반 Sony 사의 공격적인 게임 출시전략에도 불구하고 판매량은 닌텐도 사에 밀림
# 2000년대 초반부터 등장한 Electronic Arts 사는 출시량에 발맞춰 높은 판매량을 확보함
# 2006~2009년까지 Nintendo 사의 높은 판매량은 잠시 상승했던 Wii의 인기와 일맥상통
# 전반적으로 게임 판매량은 특정 게임회사의 영향력보다 출시한 게임 자체의 영향을 많이 받았던 것으로 보임

# %%
pubs_grouped_table
# Out:
#                            게임회사명  북미 판매량  유럽 판매량  일본 판매량  그외 판매량  전세계 판매량
# 368                     Nintendo  817.28  418.90  455.77   95.34  1787.29
# 140              Electronic Arts  595.07  371.27   14.04  129.77  1110.15
# 22                    Activision  429.70  215.53    6.54   75.34   727.11
# 466  Sony Computer Entertainment  265.89  187.97   74.10   80.47   608.43
# 536                      Ubisoft  253.43  163.32    7.50   50.26   474.51
# 504         Take-Two Interactive  220.49  118.14    5.83   55.24   399.70

# %%
sales_column_list_pub
# Out:
# Index(['북미 판매량', '유럽 판매량', '일본 판매량', '그외 판매량', '전세계 판매량'], dtype='object')

# %%
# 3-4. 지역별 가장 많은 게임 판매량을 기록한 게임회사 TOP 3 - 바차트

# pub_sales = df[['Publisher', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']] # in # 3-1. 게임회사별 판매량
# pub_sales.columns = ['게임회사명', '북미 판매량', '유럽 판매량', '일본 판매량', '그외 판매량', '전세계 판매량']
# pubs_grouped = pub_sales.groupby(['게임회사명']).sum()
# pubs_grouped_table = pubs_grouped.reset_index().sort_values(by=['전세계 판매량'], ascending=False).head(6) # 데이터셋 내 전체 591개 게임회사 중 판매량 상위 6개 회사만 대상으로 시각화 진행
# pubs_grouped_table.head() # pubs_grouped_table.shape: (6, 6)

sales_column_list_pub = pubs_grouped_table.columns[1:]

def pub_top3(df, sales_column_list_pub):
    df_new_pub = df.loc[:,['게임회사명', sales_column_list_pub]].sort_values(by = sales_column_list_pub, ascending = False).reset_index(drop = True).head(3)
    df_new_pub.columns = ['게임회사명', '판매량']
    return df_new_pub

pub_top3_na = pub_top3(pubs_grouped_table, '북미 판매량')
pub_top3_eu = pub_top3(pubs_grouped_table, '유럽 판매량')
pub_top3_jp = pub_top3(pubs_grouped_table, '일본 판매량')
pub_top3_other = pub_top3(pubs_grouped_table, '그외 판매량')
pub_top3_global = pub_top3(pubs_grouped_table, '전세계 판매량')
# pub_top3_na # 북미 판매량 top3 확인

pub_top3_list = [pub_top3_na, pub_top3_eu, pub_top3_jp, pub_top3_other, pub_top3_global]
# pub_top3_list

fig, axes = plt.subplots(figsize = (35, 10), nrows = 1, ncols = 5)
for col, i, data in zip(sales_column_list_pub, range(len(sales_column_list_pub)), pub_top3_list):
    axes[i].set_title(col + ' ' + 'TOP 3', fontsize = 24, pad = 10)
    sns.barplot(x = '게임회사명', y = '판매량', data = data, ax = axes[i])
    axes[i].tick_params(axis = 'both', labelsize = 10)
    axes[i].set_xlabel('게임회사명', fontsize = 16)
    axes[i].set_ylabel('판매량', fontsize = 16)
plt.show()

# %%
pubs_grouped.reset_index().sort_values(by=['일본 판매량'], ascending=False).head(6)
# Out:
#                             게임회사명  북미 판매량  유럽 판매량  일본 판매량  그외 판매량  전세계 판매량
# 368                      Nintendo  817.28  418.90  455.77   95.34  1787.29
# 356            Namco Bandai Games   69.67   42.68  127.34   14.70   254.39
# 284  Konami Digital Entertainment   92.16   69.69   91.40   30.31   283.56
# 466   Sony Computer Entertainment  265.89  187.97   74.10   80.47   608.43
# 86                         Capcom   78.59   39.22   68.13   14.84   200.78
# 456                          Sega  109.40   82.00   57.03   24.52   272.95

# %%
pubs_grouped.reset_index().sort_values(by=['전세계 판매량'], ascending=False).head(6)
# Out:
#                            게임회사명  북미 판매량  유럽 판매량  일본 판매량  그외 판매량  전세계 판매량
# 368                     Nintendo  817.28  418.90  455.77   95.34  1787.29
# 140              Electronic Arts  595.07  371.27   14.04  129.77  1110.15
# 22                    Activision  429.70  215.53    6.54   75.34   727.11
# 466  Sony Computer Entertainment  265.89  187.97   74.10   80.47   608.43
# 536                      Ubisoft  253.43  163.32    7.50   50.26   474.51
# 504         Take-Two Interactive  220.49  118.14    5.83   55.24   399.70

# %%
pubs_grouped.reset_index().sort_values(by=['전세계 판매량'], ascending=False).head(6)

# %%
# 3-4. 지역별 가장 많은 게임 판매량을 기록한 게임회사 TOP 3 - 바차트 (수정)

sales_column_list_pub = ['북미 판매량', '유럽 판매량', '일본 판매량', '그외 판매량', '전세계 판매량']

def pub_top3(df, sales_column_list_pub):
    df_new_pub = df.loc[:,['게임회사명', sales_column_list_pub]].sort_values(by = sales_column_list_pub, ascending = False).reset_index(drop = True).head(3)
    df_new_pub.columns = ['게임회사명', '판매량']
    return df_new_pub

pubs_grouped_table_na = pubs_grouped.reset_index().sort_values(by=['북미 판매량'], ascending=False)
pubs_grouped_table_eu = pubs_grouped.reset_index().sort_values(by=['유럽 판매량'], ascending=False)
pubs_grouped_table_jp = pubs_grouped.reset_index().sort_values(by=['일본 판매량'], ascending=False)
pubs_grouped_table_other = pubs_grouped.reset_index().sort_values(by=['그외 판매량'], ascending=False)
pubs_grouped_table_global = pubs_grouped.reset_index().sort_values(by=['전세계 판매량'], ascending=False)

pub_top3_na = pub_top3(pubs_grouped_table_na, '북미 판매량')
pub_top3_eu = pub_top3(pubs_grouped_table_eu, '유럽 판매량')
pub_top3_jp = pub_top3(pubs_grouped_table_jp, '일본 판매량')
pub_top3_other = pub_top3(pubs_grouped_table_other, '그외 판매량')
pub_top3_global = pub_top3(pubs_grouped_table_global, '전세계 판매량')
# pub_top3_na # 북미 판매량 top3 확인

pub_top3_list = [pub_top3_na, pub_top3_eu, pub_top3_jp, pub_top3_other, pub_top3_global]
# pub_top3_list

fig, axes = plt.subplots(figsize = (35, 10), nrows = 1, ncols = 5)
for col, i, data in zip(sales_column_list_pub, range(len(sales_column_list_pub)), pub_top3_list):
    axes[i].set_title(col + ' ' + 'TOP 3', fontsize = 24, pad = 10)
    sns.barplot(x = '게임회사명', y = '판매량', data = data, ax = axes[i])
    axes[i].tick_params(axis = 'both', labelsize = 8)
    axes[i].set_xlabel('게임회사명', fontsize = 16)
    axes[i].set_ylabel('판매량', fontsize = 16)
plt.show()

# %%
# 3-4-1. 지역별 가장 많은 게임 판매량을 기록한 게임회사 TOP 5 - 파이차트

# sales_column_list_pub = pubs_grouped_table.columns[1:]

def pub1_top5(df, sales_column_list_pub):
    df_new_pub1 = df.loc[:,['게임회사명', sales_column_list_pub]].sort_values(by = sales_column_list_pub, ascending = False).reset_index(drop = True).head(5)
    df_new_pub1.columns = ['게임회사명', '판매량']
    return df_new_pub1

pub1_top5_na = pub1_top5(pubs_grouped_table, '북미 판매량')
pub1_top5_eu = pub1_top5(pubs_grouped_table, '유럽 판매량')
pub1_top5_jp = pub1_top5(pubs_grouped_table, '일본 판매량')
pub1_top5_other = pub1_top5(pubs_grouped_table, '그외 판매량')
pub1_top5_global = pub1_top5(pubs_grouped_table, '전세계 판매량')
# pub1_top5_na # 북미 판매량 top5 확인

pub1_top5_list = [pub1_top5_na, pub1_top5_eu, pub1_top5_jp, pub1_top5_other, pub1_top5_global]
# pub1_top5_list

fig, axes = plt.subplots(1, 5, figsize = (25, 8))
plt.subplots_adjust(wspace = 0.2) # subplots간의 너비 간격 조절

# 각 subplot에 pie plot 그리기
explode = (0.1, 0.1, 0.1, 0, 0) # 퍼짐 정도 조절
for i in range(len(sales_column_list_pub)):
	ax = axes[i] # subplot 선택
	wedges, texts, autotexts = ax.pie(pub1_top5_list[i].판매량, explode = explode, labels = pub1_top5_list[i].게임회사명,
	                                  autopct = '%.1f%%', pctdistance = 0.85,
	                                  shadow = False, startangle = 30)
	for w in wedges: # 조각 설정
		w.set_linewidth(0)
		w.set_edgecolor('w')
		
	for t in texts: # label 설정
		t.set_color('k')
		t.set_fontsize(12)
		
	for a in autotexts: # 퍼센티지 설정
		a.set_color('black')
		a.set_fontsize(14)
    
	centre_circle = plt.Circle((0,0), 0.7, color='black', fc='white', linewidth=0) # 파이차트를 도넛차트로 보이게 하는 trick
	ax.add_artist(centre_circle)
	axes[i].set_title(sales_column_list_pub[i] + ' ' + 'TOP 5', fontsize = 24, pad = 2)
	ax.axis('equal')

# %%
# 3-4-1. 지역별 가장 많은 게임 판매량을 기록한 게임회사 TOP 5 - 파이차트 (수정)

# sales_column_list_pub = ['북미 판매량', '유럽 판매량', '일본 판매량', '그외 판매량', '전세계 판매량']

# pubs_grouped_table_na = pubs_grouped.reset_index().sort_values(by=['북미 판매량'], ascending=False)
# pubs_grouped_table_eu = pubs_grouped.reset_index().sort_values(by=['유럽 판매량'], ascending=False)
# pubs_grouped_table_jp = pubs_grouped.reset_index().sort_values(by=['일본 판매량'], ascending=False)
# pubs_grouped_table_other = pubs_grouped.reset_index().sort_values(by=['그외 판매량'], ascending=False)
# pubs_grouped_table_global = pubs_grouped.reset_index().sort_values(by=['전세계 판매량'], ascending=False)

def pub1_top5(df, sales_column_list_pub):
    df_new_pub1 = df.loc[:,['게임회사명', sales_column_list_pub]].sort_values(by = sales_column_list_pub, ascending = False).reset_index(drop = True).head(5)
    df_new_pub1.columns = ['게임회사명', '판매량']
    return df_new_pub1

pub1_top5_na = pub1_top5(pubs_grouped_table_na, '북미 판매량')
pub1_top5_eu = pub1_top5(pubs_grouped_table_eu, '유럽 판매량')
pub1_top5_jp = pub1_top5(pubs_grouped_table_jp, '일본 판매량')
pub1_top5_other = pub1_top5(pubs_grouped_table_other, '그외 판매량')
pub1_top5_global = pub1_top5(pubs_grouped_table_global, '전세계 판매량')
# pub1_top5_na # 북미 판매량 top5 확인

pub1_top5_list = [pub1_top5_na, pub1_top5_eu, pub1_top5_jp, pub1_top5_other, pub1_top5_global]
# pub1_top5_list

fig, axes = plt.subplots(1, 5, figsize = (25, 8))
plt.subplots_adjust(wspace = 0.2) # subplots간의 너비 간격 조절

# 각 subplot에 pie plot 그리기
explode = (0.1, 0.1, 0.1, 0, 0) # 퍼짐 정도 조절
for i in range(len(sales_column_list_pub)):
	ax = axes[i] # subplot 선택
	wedges, texts, autotexts = ax.pie(pub1_top5_list[i].판매량, explode = explode, labels = pub1_top5_list[i].게임회사명,
	                                  autopct = '%.1f%%', pctdistance = 0.85,
	                                  shadow = False, startangle = 30)
	for w in wedges: # 조각 설정
		w.set_linewidth(0)
		w.set_edgecolor('w')
		
	for t in texts: # label 설정
		t.set_color('k')
		t.set_fontsize(12)
		
	for a in autotexts: # 퍼센티지 설정
		a.set_color('black')
		a.set_fontsize(14)
    
	centre_circle = plt.Circle((0,0), 0.7, color='black', fc='white', linewidth=0) # 파이차트를 도넛차트로 보이게 하는 trick
	ax.add_artist(centre_circle)
	axes[i].set_title(sales_column_list_pub[i] + ' ' + 'TOP 5', fontsize = 24, pad = 2)
	ax.axis('equal')

# %%
pubs_grouped.reset_index().sort_values(by=['일본 판매량'], ascending=False)
# Out:
#                             게임회사명  북미 판매량  유럽 판매량  일본 판매량  그외 판매량  전세계 판매량
# 368                      Nintendo  817.28  418.90  455.77   95.34  1787.29
# 356            Namco Bandai Games   69.67   42.68  127.34   14.70   254.39
# 284  Konami Digital Entertainment   92.16   69.69   91.40   30.31   283.56
# 466   Sony Computer Entertainment  265.89  187.97   74.10   80.47   608.43
# 86                         Capcom   78.59   39.22   68.13   14.84   200.78
# ..                            ...     ...     ...     ...     ...      ...
# 257    Interworks Unlimited, Inc.    0.01    0.00    0.00    0.00     0.01
# 256         Interplay Productions    0.05    0.04    0.00    0.01     0.10
# 251               Insomniac Games    0.10    0.00    0.00    0.01     0.11
# 246                        Imagic    4.51    0.27    0.00    0.04     4.82
# 589                  responDESIGN    0.09    0.04    0.00    0.01     0.14
#
# [590 rows x 6 columns]

# %%
pubs_grouped.reset_index().sort_values(by=['전세계 판매량'], ascending=False)
# Out:
#                            게임회사명  북미 판매량  유럽 판매량  일본 판매량  그외 판매량  전세계 판매량
# 368                     Nintendo  817.28  418.90  455.77   95.34  1787.29
# 140              Electronic Arts  595.07  371.27   14.04  129.77  1110.15
# 22                    Activision  429.70  215.53    6.54   75.34   727.11
# 466  Sony Computer Entertainment  265.89  187.97   74.10   80.47   608.43
# 536                      Ubisoft  253.43  163.32    7.50   50.26   474.51
# ..                           ...     ...     ...     ...     ...      ...
# 194             Gearbox Software    0.01    0.00    0.00    0.00     0.01
# 197                  Genterprise    0.00    0.00    0.01    0.00     0.01
# 359                   Naxat Soft    0.00    0.00    0.01    0.00     0.01
# 535            UIG Entertainment    0.00    0.01    0.00    0.00     0.01
# 505                       Takuyo    0.00    0.00    0.01    0.00     0.01
#
# [590 rows x 6 columns]

# %%
df.sort_values(by = 'Global_Sales', ascending = False)
# Out:
#                                                     Name Platform  Year  \
# 2908                                          Wii Sports      Wii  2006
# 4199                                   Super Mario Bros.      NES  1985
# 12579                                     Mario Kart Wii      Wii  2008
# 3352                                   Wii Sports Resort      Wii  2009
# 7829                            Pokemon Red/Pokemon Blue       GB  1996
# ...                                                  ...      ...   ...
# 14265         Nitroplus Blasterz: Heroines Infinite Duel      PS3  2015
# 2311   Shinseiki Evangelion: Koutetsu no Girlfriend 2...      PSP  2009
# 11376                                     Rail Simulator       PC  2007
# 3571                         Hyperdimension Neptunia mk2      PS3  2011
# 5598    SCORE International Baja 1000: The Official Game      PS2  2008
#
#               Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 2908         Sports              Nintendo     41.49     29.02      3.77
# 4199       Platform              Nintendo     29.08      3.58      6.81
# 12579        Racing              Nintendo     15.85     12.88      3.79
# 3352         Sports              Nintendo     15.75     11.01      3.28
# 7829   Role-Playing              Nintendo     11.27      8.89     10.22
# ...             ...                   ...       ...       ...       ...
# 14265      Fighting             Nitroplus      0.00      0.00      0.01
# 2311      Adventure            CyberFront      0.00      0.00      0.01
# 11376    Simulation       Electronic Arts      0.00      0.01      0.00
# 3571         Action  Nippon Ichi Software      0.00      0.01      0.00
# 5598         Racing            Activision      0.00      0.00      0.00
#
#        Other_Sales  Global_Sales
# 2908          8.46         82.74
# 4199          0.77         40.24
# 12579         3.31         35.83
# 3352          2.96         33.00
# 7829          1.00         31.38
# ...            ...           ...
# 14265         0.00          0.01
# 2311          0.00          0.01
# 11376         0.00          0.01
# 3571          0.00          0.01
# 5598          0.00          0.00
#
# [16598 rows x 10 columns]

# %%
df.loc[df.Name.str.contains('Call of Duty')].sort_values(by = 'Year', ascending = False)
# Out:
#                                                Name Platform  Year     Genre  \
# 12986                       Call of Duty: Black Ops       PC  2020  Shooting
# 3465           Call of Duty: Modern Warfare Trilogy      PS3  2016  Shooting
# 2795           Call of Duty: Modern Warfare Trilogy     X360  2016  Shooting
# 11892                     Call of Duty: Black Ops 3       PC  2015  Shooting
# 12266                     Call of Duty: Black Ops 3     X360  2015  Shooting
# 12841                     Call of Duty: Black Ops 3      PS3  2015  Shooting
# 15981                     Call of Duty: Black Ops 3     XOne  2015  Shooting
# 9070                      Call of Duty: Black Ops 3      PS4  2015  Shooting
# 7142                 Call of Duty: Advanced Warfare      PS4  2014  Shooting
# 14243                Call of Duty: Advanced Warfare     X360  2014  Shooting
# 16497                Call of Duty: Advanced Warfare       PC  2014  Shooting
# 474                  Call of Duty: Advanced Warfare      PS3  2014  Shooting
# 15314                Call of Duty: Advanced Warfare     XOne  2014  Shooting
# 866                            Call of Duty: Ghosts       PC  2013  Shooting
# 5604                           Call of Duty: Ghosts     X360  2013  Shooting
# 5673                           Call of Duty: Ghosts     WiiU  2013  Shooting
# 9791                           Call of Duty: Ghosts      PS4  2013  Shooting
# 12978                          Call of Duty: Ghosts     XOne  2013  Shooting
# 6881                           Call of Duty: Ghosts      PS3  2013  Shooting
# 15169          Call of Duty Black Ops: Declassified      PSV  2012    Action
# 4240                     Call of Duty: Black Ops II      PS3  2012  Shooting
# 10626                    Call of Duty: Black Ops II     WiiU  2012  Shooting
# 6393                     Call of Duty: Black Ops II     X360  2012  Shooting
# 9048                     Call of Duty: Black Ops II       PC  2012  Shooting
# 8336       Call of Duty: Modern Warfare 3: Defiance       DS  2011  Shooting
# 11180                Call of Duty: Modern Warfare 3       PC  2011  Shooting
# 2809                 Call of Duty: Modern Warfare 3     X360  2011  Shooting
# 14120                Call of Duty: Modern Warfare 3      PS3  2011  Shooting
# 4992                 Call of Duty: Modern Warfare 3      Wii  2011  Shooting
# 13216                       Call of Duty: Black Ops       DS  2010  Shooting
# 7120                        Call of Duty: Black Ops      Wii  2010  Shooting
# 6248                        Call of Duty: Black Ops     X360  2010  Shooting
# 9924                        Call of Duty: Black Ops      PS3  2010  Shooting
# 5271               Call of Duty: The War Collection     X360  2010  Shooting
# 8374                 Call of Duty: Modern Warfare 2      PS3  2009  Shooting
# 2389   Call of Duty: Modern Warfare: Reflex Edition      Wii  2009  Shooting
# 11865       Call of Duty: Modern Warfare: Mobilized       DS  2009  Shooting
# 3131                 Call of Duty: Modern Warfare 2       PC  2009  Shooting
# 6236                 Call of Duty: Modern Warfare 2     X360  2009  Shooting
# 14468                    Call of Duty: World at War      Wii  2008  Shooting
# 8715                     Call of Duty: World at War      PS3  2008  Shooting
# 10972       Call of Duty: World at War Final Fronts      PS2  2008  Shooting
# 10937                    Call of Duty: World at War     X360  2008  Shooting
# 9275                     Call of Duty: World at War       PC  2008  Shooting
# 11524                    Call of Duty: World at War       DS  2008  Shooting
# 122                  Call of Duty 4: Modern Warfare     X360  2007  Shooting
# 4226                 Call of Duty 4: Modern Warfare      PS3  2007  Shooting
# 11931                Call of Duty: Roads to Victory      PSP  2007  Shooting
# 12767                Call of Duty 4: Modern Warfare       DS  2007  Shooting
# 131                  Call of Duty 4: Modern Warfare       PC  2007  Shooting
# 2130                                 Call of Duty 3      Wii  2006  Shooting
# 11774                                Call of Duty 3      PS3  2006  Shooting
# 12153                                Call of Duty 3     X360  2006  Shooting
# 7427                                 Call of Duty 3      PS2  2006  Shooting
# 5281                                 Call of Duty 2     X360  2005  Shooting
# 1922                                 Call of Duty 2       PC  2005  Shooting
# 4273                      Call of Duty: Finest Hour       GC  2004  Shooting
# 14448                     Call of Duty: Finest Hour      PS2  2004  Shooting
# 3331                      Call of Duty: Finest Hour       XB  2004  Shooting
#
#         Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 12986  Activision      0.58      0.81      0.00         0.24          1.63
# 3465   Activision      0.00      0.01      0.00         0.00          0.01
# 2795   Activision      0.01      0.01      0.00         0.00          0.02
# 11892  Activision      0.00      0.22      0.00         0.01          0.23
# 12266  Activision      1.11      0.48      0.00         0.16          1.75
# 12841  Activision      0.49      0.96      0.07         0.27          1.79
# 15981  Activision      4.52      2.09      0.01         0.67          7.29
# 9070   Activision      5.77      5.81      0.35         2.31         14.24
# 7142   Activision      2.80      3.30      0.14         1.37          7.61
# 14243  Activision      2.75      1.18      0.00         0.37          4.30
# 16497  Activision      0.14      0.23      0.00         0.04          0.41
# 474    Activision      1.54      1.94      0.19         0.77          4.44
# 15314  Activision      3.21      1.53      0.01         0.38          5.13
# 866    Activision      0.23      0.41      0.00         0.09          0.73
# 5604   Activision      6.72      2.63      0.04         0.82         10.21
# 5673   Activision      0.23      0.09      0.01         0.03          0.36
# 9791   Activision      1.78      1.42      0.05         0.38          3.63
# 12978  Activision      1.87      0.77      0.00         0.22          2.86
# 6881   Activision      4.09      3.73      0.38         1.38          9.58
# 15169  Activision      0.80      0.52      0.07         0.30          1.69
# 4240   Activision      4.99      5.88      0.65         2.52         14.04
# 10626  Activision      0.21      0.18      0.00         0.03          0.42
# 6393   Activision      8.25      4.30      0.07         1.12         13.74
# 9048   Activision      0.63      0.69      0.00         0.21          1.53
# 8336   Activision      0.21      0.07      0.00         0.02          0.30
# 11180  Activision      0.41      0.98      0.00         0.33          1.72
# 2809   Activision      9.03      4.28      0.13         1.32         14.76
# 14120  Activision      5.54      5.82      0.49         1.62         13.47
# 4992   Activision      0.60      0.21      0.00         0.08          0.89
# 13216  Activision      0.54      0.05      0.00         0.04          0.63
# 7120   Activision      0.82      0.47      0.00         0.12          1.41
# 6248   Activision      9.67      3.73      0.11         1.13         14.64
# 9924   Activision      5.98      4.44      0.48         1.83         12.73
# 5271   Activision      0.05      0.00      0.00         0.00          0.05
# 8374   Activision      4.99      3.69      0.38         1.63         10.69
# 2389   Activision      0.95      0.43      0.00         0.14          1.52
# 11865  Activision      0.37      0.02      0.00         0.03          0.42
# 3131   Activision      0.01      0.79      0.00         0.09          0.89
# 6236   Activision      8.52      3.63      0.08         1.29         13.52
# 14468  Activision      1.20      0.59      0.00         0.19          1.98
# 8715   Activision      2.72      1.87      0.00         0.84          5.43
# 10972  Activision      0.61      0.18      0.00         0.94          1.73
# 10937  Activision      4.79      1.90      0.00         0.69          7.38
# 9275   Activision      0.02      0.13      0.00         0.03          0.18
# 11524  Activision      0.57      0.26      0.00         0.08          0.91
# 122    Activision      5.91      2.38      0.13         0.90          9.32
# 4226   Activision      3.10      2.30      0.28         1.04          6.72
# 11931  Activision      0.52      1.03      0.00         0.59          2.14
# 12767  Activision      0.96      0.02      0.01         0.08          1.07
# 131    Activision      0.00      1.12      0.00         0.03          1.15
# 2130   Activision      1.19      0.84      0.00         0.23          2.26
# 11774  Activision      0.60      0.63      0.03         0.26          1.52
# 12153  Activision      1.49      0.93      0.02         0.27          2.71
# 7427   Activision      0.89      0.03      0.00         0.15          1.07
# 5281   Activision      1.81      0.05      0.01         0.15          2.02
# 1922   Activision      0.00      0.05      0.00         0.01          0.06
# 4273   Activision      0.31      0.08      0.00         0.01          0.40
# 14448  Activision      1.51      1.12      0.01         0.24          2.88
# 3331   Activision      0.78      0.40      0.00         0.04          1.22

# %%
df.loc[((df.Year == 2006) & (df.Publisher == 'Nintendo'))].sort_values(by = 'Global_Sales', ascending = False)
# Out:
#                                                     Name Platform  Year  \
# 2908                                          Wii Sports      Wii  2006
# 6937                               New Super Mario Bros.       DS  2006
# 3014                                            Wii Play      Wii  2006
# 10555                      Pokemon Diamond/Pokemon Pearl       DS  2006
# 1035              The Legend of Zelda: Twilight Princess      Wii  2006
# 9867                                     Clubhouse Games       DS  2006
# 9508   English Training: Have Fun Improving Your Skills!       DS  2006
# 14352                          Personal Trainer: Cooking       DS  2006
# 2438                             WarioWare: Smooth Moves      Wii  2006
# 5315                                   Yoshi's Island DS       DS  2006
# 6632                                      Pokemon Ranger       DS  2006
# 1481                                           Tetris DS       DS  2006
# 2751                                  Kirby Squeak Squad       DS  2006
# 8156   Kanshuu Nippon Joushikiryoku Kentei Kyoukai: I...       DS  2006
# 13930                                 Mario Hoops 3 on 3       DS  2006
# 12667                          Pokemon Battle Revolution      Wii  2006
# 16094             The Legend of Zelda: Twilight Princess       GC  2006
# 12073        Mario vs. Donkey Kong 2: March of the Minis       DS  2006
# 2091                               Metroid Prime Hunters       DS  2006
# 9381                                 Jump Ultimate Stars       DS  2006
# 14004                                       Excite Truck      Wii  2006
# 8466                                    Star Fox Command       DS  2006
# 4584         Kenkou Ouen Recipe 1000: DS Kondate Zenshuu       DS  2006
# 10933                                   Children of Mana       DS  2006
# 12440                                 Master of Illusion       DS  2006
# 16387                                           Mother 3      GBA  2006
# 792                                    Elite Beat Agents       DS  2006
# 8619                       Trauma Center: Second Opinion      Wii  2006
# 12479                                     Rhythm Tengoku      GBA  2006
# 6574                            Final Fantasy VI Advance      GBA  2006
# 15494                            Final Fantasy V Advance      GBA  2006
# 10203            Freshly-Picked: Tingle's Rosy Rupeeland       DS  2006
# 6333                                    Super Swing Golf      Wii  2006
# 16239                        Magical Starsign (US sales)       DS  2006
# 6247                        Sudoku Gridmaster (JP sales)       DS  2006
# 12727                                  Sudoku Gridmaster       DS  2006
# 153                                  Densetsu no Stafi 4       DS  2006
# 15498                                  Custom Robo Arena       DS  2006
# 14586                            Kororinpa: Marble Mania      Wii  2006
# 6012                                           Magnetica       DS  2006
# 14798                      Eyeshield 21: Max Devil Power       DS  2006
# 10350                                              Odama       GC  2006
# 16045                            Project Hacker: Kakusei       DS  2006
# 749    Tabi no Yubisashi Kaiwachou DS: DS Series 4 Am...       DS  2006
# 14630                   Kanji Sonomama DS Rakubiki Jiten       DS  2006
# 2970                                Chou Soujuu Mecha MG       DS  2006
# 4661   Tabi no Yubisashi Kaiwachou DS: DS Series 3 Ka...       DS  2006
# 15465  Tabi no Yubisashi Kaiwachou DS: DS Series 2 Ch...       DS  2006
# 15568                    Mawashite Tsunageru Touch Panic       DS  2006
# 15811   Tabi no Yubisashi Kaiwachou DS: DS Series 1 Thai       DS  2006
# 1631                         Magical Starsign (JP sales)       DS  2006
# 14748  Tabi no Yubisashi Kaiwachou DS: DS Series 5 De...       DS  2006
# 12789                                         Calcio Bit      GBA  2006
# 913                    Eyeshield 21: DevilBats DevilDays      GBA  2006
#
#               Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 2908         Sports  Nintendo     41.49     29.02      3.77         8.46
# 6937       Platform  Nintendo     11.38      9.23      6.50         2.90
# 3014           Misc  Nintendo     14.03      9.20      2.93         2.85
# 10555  Role-Playing  Nintendo      6.42      4.52      6.04         1.37
# 1035         Action  Nintendo      3.83      2.19      0.60         0.70
# 9867           Misc  Nintendo      0.59      1.83      0.73         0.35
# 9508           Misc  Nintendo      0.00      0.99      2.32         0.02
# 14352          Misc  Nintendo      0.91      1.00      1.03         0.17
# 2438         Puzzle  Nintendo      0.87      1.06      0.73         0.26
# 5315       Platform  Nintendo      1.47      0.07      1.10         0.15
# 6632   Role-Playing  Nintendo      1.29      0.04      0.73         0.12
# 1481         Puzzle  Nintendo      0.64      0.07      1.35         0.08
# 2751       Platform  Nintendo      0.79      0.03      1.05         0.08
# 8156           Misc  Nintendo      0.00      0.00      1.71         0.00
# 13930        Sports  Nintendo      0.99      0.04      0.49         0.10
# 12667  Role-Playing  Nintendo      0.80      0.38      0.30         0.13
# 16094        Action  Nintendo      1.15      0.36      0.04         0.04
# 12073        Puzzle  Nintendo      0.74      0.03      0.36         0.07
# 2091       Shooting  Nintendo      0.58      0.04      0.11         0.06
# 9381       Fighting  Nintendo      0.00      0.00      0.74         0.00
# 14004        Racing  Nintendo      0.40      0.03      0.08         0.04
# 8466       Shooting  Nintendo      0.39      0.01      0.10         0.04
# 4584           Misc  Nintendo      0.00      0.00      0.52         0.00
# 10933  Role-Playing  Nintendo      0.16      0.01      0.29         0.02
# 12440        Puzzle  Nintendo      0.16      0.00      0.26         0.01
# 16387  Role-Playing  Nintendo      0.00      0.00      0.39         0.01
# 792            Misc  Nintendo      0.31      0.03      0.00         0.03
# 8619     Simulation  Nintendo      0.28      0.02      0.03         0.03
# 12479          Misc  Nintendo      0.00      0.00      0.30         0.01
# 6574   Role-Playing  Nintendo      0.00      0.00      0.28         0.01
# 15494  Role-Playing  Nintendo      0.00      0.00      0.26         0.01
# 10203  Role-Playing  Nintendo      0.00      0.01      0.24         0.00
# 6333         Sports  Nintendo      0.14      0.01      0.07         0.01
# 16239  Role-Playing  Nintendo      0.16      0.03      0.00         0.00
# 6247         Puzzle  Nintendo      0.00      0.00      0.19         0.00
# 12727        Puzzle  Nintendo      0.13      0.03      0.00         0.01
# 153        Platform  Nintendo      0.00      0.00      0.17         0.00
# 15498      Fighting  Nintendo      0.02      0.02      0.12         0.00
# 14586        Puzzle  Nintendo      0.08      0.02      0.03         0.01
# 6012         Puzzle  Nintendo      0.08      0.01      0.03         0.01
# 14798  Role-Playing  Nintendo      0.00      0.00      0.12         0.00
# 10350          Misc  Nintendo      0.07      0.02      0.02         0.00
# 16045        Action  Nintendo      0.00      0.00      0.10         0.00
# 749            Misc  Nintendo      0.00      0.00      0.09         0.00
# 14630          Misc  Nintendo      0.00      0.00      0.07         0.00
# 2970     Simulation  Nintendo      0.00      0.00      0.06         0.00
# 4661           Misc  Nintendo      0.00      0.00      0.06         0.00
# 15465          Misc  Nintendo      0.00      0.00      0.05         0.00
# 15568        Puzzle  Nintendo      0.00      0.00      0.05         0.00
# 15811          Misc  Nintendo      0.00      0.00      0.05         0.00
# 1631   Role-Playing  Nintendo      0.00      0.00      0.04         0.00
# 14748          Misc  Nintendo      0.00      0.00      0.04         0.00
# 12789        Sports  Nintendo      0.00      0.00      0.03         0.00
# 913    Role-Playing  Nintendo      0.00      0.00      0.03         0.00
#
#        Global_Sales
# 2908          82.74
# 6937          30.01
# 3014          29.01
# 10555         18.35
# 1035           7.32
# 9867           3.50
# 9508           3.33
# 14352          3.11
# 2438           2.92
# 5315           2.79
# 6632           2.18
# 1481           2.14
# 2751           1.95
# 8156           1.71
# 13930          1.62
# 12667          1.61
# 16094          1.59
# 12073          1.20
# 2091           0.79
# 9381           0.74
# 14004          0.55
# 8466           0.54
# 4584           0.52
# 10933          0.48
# 12440          0.43
# 16387          0.40
# 792            0.37
# 8619           0.36
# 12479          0.31
# 6574           0.29
# 15494          0.27
# 10203          0.25
# 6333           0.23
# 16239          0.19
# 6247           0.19
# 12727          0.17
# 153            0.17
# 15498          0.16
# 14586          0.14
# 6012           0.13
# 14798          0.12
# 10350          0.11
# 16045          0.10
# 749            0.09
# 14630          0.07
# 2970           0.06
# 4661           0.06
# 15465          0.05
# 15568          0.05
# 15811          0.05
# 1631           0.04
# 14748          0.04
# 12789          0.03
# 913            0.03

# %%
df.loc[((df.Year == 2009) & (df.Publisher == 'Nintendo'))].sort_values(by = 'Global_Sales', ascending = False)
# Out:
#                                                     Name Platform  Year  \
# 3352                                   Wii Sports Resort      Wii  2009
# 16531                          New Super Mario Bros. Wii      Wii  2009
# 10899                                       Wii Fit Plus      Wii  2009
# 4806                Pokemon HeartGold/Pokemon SoulSilver       DS  2009
# 5218      Dragon Quest IX: Sentinels of the Starry Skies       DS  2009
# 4568                Mario & Luigi: Bowser's Inside Story       DS  2009
# 8212                                   Friend Collection       DS  2009
# 14035                 The Legend of Zelda: Spirit Tracks       DS  2009
# 10665              Professor Layton and the Last Specter       DS  2009
# 9963                                  Monster Hunter Tri      Wii  2009
# 1925           Pokemon Mystery Dungeon: Explorers of Sky       DS  2009
# 7335                New Play Control! Mario Power Tennis      Wii  2009
# 941                                     Inazuma Eleven 2       DS  2009
# 4254                   PokéPark Wii: Pikachu's Adventure      Wii  2009
# 10517                          Endless Ocean: Blue World      Wii  2009
# 11185                             Metroid Prime: Trilogy      Wii  2009
# 2817                                    WarioWare D.I.Y.       DS  2009
# 1075                          New Play Control! Pikmin 2      Wii  2009
# 10930      Naruto Shippuden: Clash of Ninja Revolution 3      Wii  2009
# 14862                                         Picross 3D       DS  2009
# 3393                                  Samurai Warriors 3      Wii  2009
# 2465                  Sin and Punishment: Star Successor      Wii  2009
# 2732                            ExciteBots: Trick Racing      Wii  2009
# 591              Nintendo Presents: Crossword Collection       DS  2009
# 2086                  Active Health with Carol Vorderman       DS  2009
# 13792           Okaeri! Chibi-Robo! Happy Richie Oosouji       DS  2009
# 9563               Irozuki Tingle no Koi no Balloon Trip       DS  2009
# 14558  Nihon Keizai Shinbunsha Kanshuu: Shiranai Mama...       DS  2009
# 14995                                 DS Uranai Seikatsu       DS  2009
# 11860       Another Code R: A Journey into Lost Memories      Wii  2009
# 7175                            Wii de Asobu Chibi-Robo!      Wii  2009
# 14420        Minna ga Shuyaku no NHK Kouhaku Quiz Kassen      Wii  2009
#
#               Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 3352         Sports  Nintendo     15.75     11.01      3.28         2.96
# 16531      Platform  Nintendo     14.59      7.06      4.70         2.26
# 10899        Sports  Nintendo      9.09      8.59      2.53         1.79
# 4806         Action  Nintendo      4.40      2.77      3.96         0.77
# 5218   Role-Playing  Nintendo      0.66      0.69      4.35         0.15
# 4568   Role-Playing  Nintendo      2.26      0.48      0.81         0.27
# 8212           Misc  Nintendo      0.00      0.00      3.67         0.00
# 14035        Action  Nintendo      1.43      0.94      0.74         0.27
# 10665        Puzzle  Nintendo      0.30      1.47      0.68         0.34
# 9963   Role-Playing  Nintendo      0.67      0.41      1.05         0.11
# 1925   Role-Playing  Nintendo      0.58      0.44      0.44         0.12
# 7335         Sports  Nintendo      0.37      0.69      0.28         0.14
# 941    Role-Playing  Nintendo      0.00      0.21      1.18         0.03
# 4254      Adventure  Nintendo      0.55      0.17      0.42         0.06
# 10517    Simulation  Nintendo      0.47      0.22      0.12         0.07
# 11185      Shooting  Nintendo      0.43      0.05      0.00         0.14
# 2817           Misc  Nintendo      0.18      0.19      0.20         0.04
# 1075       Strategy  Nintendo      0.11      0.14      0.33         0.02
# 10930      Fighting  Nintendo      0.45      0.04      0.00         0.04
# 14862        Puzzle  Nintendo      0.30      0.03      0.16         0.03
# 3393         Action  Nintendo      0.10      0.02      0.32         0.01
# 2465       Shooting  Nintendo      0.20      0.14      0.06         0.04
# 2732         Racing  Nintendo      0.26      0.00      0.00         0.02
# 591          Puzzle  Nintendo      0.00      0.21      0.00         0.02
# 2086         Sports  Nintendo      0.00      0.18      0.00         0.01
# 13792     Adventure  Nintendo      0.00      0.00      0.14         0.00
# 9563      Adventure  Nintendo      0.00      0.00      0.11         0.00
# 14558          Misc  Nintendo      0.00      0.00      0.10         0.00
# 14995          Misc  Nintendo      0.00      0.00      0.07         0.00
# 11860     Adventure  Nintendo      0.00      0.03      0.03         0.00
# 7175      Adventure  Nintendo      0.00      0.00      0.05         0.00
# 14420          Misc  Nintendo      0.00      0.00      0.04         0.00
#
#        Global_Sales
# 3352          33.00
# 16531         28.61
# 10899         22.00
# 4806          11.90
# 5218           5.85
# 4568           3.82
# 8212           3.67
# 14035          3.38
# 10665          2.79
# 9963           2.24
# 1925           1.58
# 7335           1.48
# 941            1.42
# 4254           1.20
# 10517          0.88
# 11185          0.62
# 2817           0.61
# 1075           0.60
# 10930          0.53
# 14862          0.52
# 3393           0.45
# 2465           0.44
# 2732           0.28
# 591            0.23
# 2086           0.19
# 13792          0.14
# 9563           0.11
# 14558          0.10
# 14995          0.07
# 11860          0.06
# 7175           0.05
# 14420          0.04

# %%
df.loc[df.Year == 2006].Global_Sales.sum()
# Out:
# 527.0

# %%
df.loc[((df.Year == 2002) & (df.Publisher == 'Electronic Arts'))].sort_values(by = 'Global_Sales', ascending = False)
# Out:
#                                           Name Platform  Year       Genre  \
# 6305                 Medal of Honor: Frontline      PS2  2002    Shooting
# 10100    The Lord of the Rings: The Two Towers      PS2  2002      Action
# 15184                          Madden NFL 2003      PS2  2002      Sports
# 5393                       The Sims: Unleashed       PC  2002  Simulation
# 8471                          FIFA Soccer 2003      PS2  2002      Sports
# ...                                        ...      ...   ...         ...
# 9434        FIFA Soccer 2003 (weekly jp sales)      PS2  2002      Sports
# 12604                                  F1 2002       GC  2002      Racing
# 12864                         Battlefield 1942       PC  2002    Shooting
# 15280               Command & Conquer Renegade       PC  2002    Shooting
# 7607   Harry Potter and the Chamber of Secrets       PC  2002      Action
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 6305   Electronic Arts      2.93      2.75      0.17         0.99
# 10100  Electronic Arts      1.94      1.95      0.08         0.70
# 15184  Electronic Arts      3.36      0.21      0.01         0.56
# 5393   Electronic Arts      2.03      1.56      0.00         0.17
# 8471   Electronic Arts      0.46      2.28      0.05         0.61
# ...                ...       ...       ...       ...          ...
# 9434   Electronic Arts      0.00      0.00      0.04         0.00
# 12604  Electronic Arts      0.02      0.01      0.00         0.00
# 12864  Electronic Arts      0.01      0.01      0.00         0.00
# 15280  Electronic Arts      0.00      0.01      0.00         0.00
# 7607   Electronic Arts      0.00      0.01      0.00         0.00
#
#        Global_Sales
# 6305           6.84
# 10100          4.67
# 15184          4.14
# 5393           3.76
# 8471           3.40
# ...             ...
# 9434           0.04
# 12604          0.03
# 12864          0.02
# 15280          0.01
# 7607           0.01
#
# [90 rows x 10 columns]

# %%
df.loc[((df.Year == 2002) & (df.Publisher == 'Electronic Arts'))].Global_Sales.sum()
# Out:
# 73.75999999999999

# %%
df.loc[df.Year >= 2017].sort_values(ascending = False, by = 'Year')
# Out:
#                                                    Name Platform  Year  \
# 3895                  WRC: FIA World Rally Championship      PS3  2021
# 4124                  WRC: FIA World Rally Championship     X360  2021
# 7131                  WRC: FIA World Rally Championship       PC  2021
# 6906                             Imagine: Makeup Artist       DS  2020
# 12986                           Call of Duty: Black Ops       PC  2020
# 6354                                               GRID       DS  2019
# 13488                                              GRID       PC  2019
# 14003                              RollerCoaster Tycoon       PC  2018
# 15063                           Drake of the 99 Dragons       XB  2018
# 5310                   Brothers Conflict: Precious Baby      PSV  2017
# 10107  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4  2017
# 15233  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV  2017
#
#               Genre         Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 3895         Racing  Black Bean Games      0.00      0.15      0.01
# 4124         Racing  Black Bean Games      0.00      0.10      0.00
# 7131         Racing  Black Bean Games      0.00      0.01      0.00
# 6906     Simulation           Ubisoft      0.27      0.00      0.00
# 12986      Shooting        Activision      0.58      0.81      0.00
# 6354         Racing       Codemasters      0.04      0.01      0.00
# 13488        Racing       Codemasters      0.00      0.03      0.00
# 14003      Strategy        Microprose      0.02      0.02      0.00
# 15063      Shooting           Unknown      0.05      0.01      0.00
# 5310         Action      Idea Factory      0.00      0.00      0.01
# 10107  Role-Playing              Sega      0.00      0.00      0.03
# 15233  Role-Playing              Sega      0.00      0.00      0.01
#
#        Other_Sales  Global_Sales
# 3895          0.05          0.21
# 4124          0.02          0.12
# 7131          0.00          0.01
# 6906          0.02          0.29
# 12986         0.24          1.63
# 6354          0.00          0.05
# 13488         0.01          0.04
# 14003         0.01          0.05
# 15063         0.00          0.06
# 5310          0.00          0.01
# 10107         0.00          0.03
# 15233         0.00          0.01

# %%
df.loc[df.Genre == 'Role-Playing'].sort_values(by = 'JP_Sales', ascending = False)
# Out:
#                                                     Name Platform  Year  \
# 7829                            Pokemon Red/Pokemon Blue       GB  1996
# 9416                         Pokemon Gold/Pokemon Silver       GB  1999
# 10555                      Pokemon Diamond/Pokemon Pearl       DS  2006
# 10621                        Pokemon Black/Pokemon White       DS  2010
# 10917                      Pokemon Ruby/Pokemon Sapphire      GBA  2002
# ...                                                  ...      ...   ...
# 3993   Shin Megami Tensei: Devil Summoner 2 - Raidou ...      PS2  2008
# 11470                                              Risen     X360  2009
# 11485                          Disgaea: Hour of Darkness      PS2  2003
# 11488                     The Elder Scrolls IV: Oblivion       PC  2006
# 12                                         Mount & Blade       PC  2008
#
#               Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 7829   Role-Playing              Nintendo     11.27      8.89     10.22
# 9416   Role-Playing              Nintendo      9.00      6.18      7.20
# 10555  Role-Playing              Nintendo      6.42      4.52      6.04
# 10621  Role-Playing              Nintendo      5.57      3.28      5.65
# 10917  Role-Playing              Nintendo      6.06      3.90      5.38
# ...             ...                   ...       ...       ...       ...
# 3993   Role-Playing                 Atlus      0.07      0.05      0.00
# 11470  Role-Playing           Deep Silver      0.07      0.11      0.00
# 11485  Role-Playing            Tecmo Koei      0.16      0.13      0.00
# 11488  Role-Playing  Take-Two Interactive      0.01      0.20      0.00
# 12     Role-Playing   Paradox Interactive      0.00      0.02      0.00
#
#        Other_Sales  Global_Sales
# 7829          1.00         31.38
# 9416          0.71         23.09
# 10555         1.37         18.35
# 10621         0.82         15.32
# 10917         0.50         15.84
# ...            ...           ...
# 3993          0.02          0.14
# 11470         0.01          0.19
# 11485         0.04          0.33
# 11488         0.05          0.26
# 12            0.00          0.02
#
# [1491 rows x 10 columns]

# %%
df.loc[df.Name.str.contains('Pokemon')].sort_values(by = 'JP_Sales', ascending = False)
# Out:
#                                                     Name Platform  Year  \
# 7829                            Pokemon Red/Pokemon Blue       GB  1996
# 9416                         Pokemon Gold/Pokemon Silver       GB  1999
# 10555                      Pokemon Diamond/Pokemon Pearl       DS  2006
# 10621                        Pokemon Black/Pokemon White       DS  2010
# 10917                      Pokemon Ruby/Pokemon Sapphire      GBA  2002
# 1971                                 Pokemon X/Pokemon Y      3DS  2013
# 4806                Pokemon HeartGold/Pokemon SoulSilver       DS  2009
# 1810                   Pokemon FireRed/Pokemon LeafGreen      GBA  2004
# 15678                    Pokemon Black 2/Pokemon White 2       DS  2012
# 4251           Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS  2014
# 15894  Pokemon Mystery Dungeon: Explorers of Time/Exp...       DS  2007
# 2713                                     Pokemon Pinball       GB  1999
# 9650                                     Pokemon Stadium      N64  1999
# 14513              Pokemon Card GB2: Here Comes Team GR!       GB  2001
# 6986       Pokemon Mystery Dungeon: Red/Blue Rescue Team      GBA  2005
# 6632                                      Pokemon Ranger       DS  2006
# 16325                                       Pokemon Snap      N64  1999
# 5511                    Pokemon Ranger: Shadows of Almia       DS  2008
# 4087                      Pokemon Ranger: Guardian Signs       DS  2010
# 7840          Pokemon Mystery Dungeon: Gates to Infinity      3DS  2012
# 1925           Pokemon Mystery Dungeon: Explorers of Sky       DS  2009
# 6208                    Pokemon Pinball: Ruby & Sapphire      GBA  2003
# 5650                                        Pokemon Dash       DS  2004
# 1247                                    Pokemon Conquest       DS  2012
# 1811                                Pokemon Rumble Blast      3DS  2011
# 15554                      Pokemon Super Mystery Dungeon      3DS  2015
# 255                                      Pokemon Trozei!       DS  2005
# 9072                        Pokemon XD: Gale of Darkness       GC  2005
# 12667                          Pokemon Battle Revolution      Wii  2006
# 16245                    Battle & Get! Pokemon Typing DS       DS  2011
# 8349                        Pokemon Box: Ruby & Sapphire       GC  2003
# 1428                                 Pokemon Art Academy      3DS  2014
# 11713                               Pokemon Rumble World      3DS  2015
# 16585                                    Pokemon Channel       GC  2003
# 9527                               Pokemon Puzzle League      N64  2000
#
#               Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 7829   Role-Playing  Nintendo     11.27      8.89     10.22         1.00
# 9416   Role-Playing  Nintendo      9.00      6.18      7.20         0.71
# 10555  Role-Playing  Nintendo      6.42      4.52      6.04         1.37
# 10621  Role-Playing  Nintendo      5.57      3.28      5.65         0.82
# 10917  Role-Playing  Nintendo      6.06      3.90      5.38         0.50
# 1971   Role-Playing  Nintendo      5.17      4.05      4.34         0.79
# 4806         Action  Nintendo      4.40      2.77      3.96         0.77
# 1810   Role-Playing  Nintendo      4.34      2.65      3.15         0.35
# 15678  Role-Playing  Nintendo      2.91      1.86      3.14         0.43
# 4251   Role-Playing  Nintendo      4.23      3.37      3.08         0.65
# 15894  Role-Playing  Nintendo      1.85      1.20      1.54         0.37
# 2713           Misc  Nintendo      3.02      1.12      1.01         0.16
# 9650       Strategy  Nintendo      3.18      1.24      0.94         0.09
# 14513      Strategy  Nintendo      0.00      0.00      0.89         0.00
# 6986   Role-Playing  Nintendo      0.71      0.52      0.74         0.08
# 6632   Role-Playing  Nintendo      1.29      0.04      0.73         0.12
# 16325    Simulation  Nintendo      2.23      0.68      0.66         0.06
# 5511   Role-Playing  Nintendo      0.95      0.54      0.62         0.18
# 4087   Role-Playing  Nintendo      0.51      0.17      0.58         0.06
# 7840   Role-Playing  Nintendo      0.44      0.30      0.47         0.06
# 1925   Role-Playing  Nintendo      0.58      0.44      0.44         0.12
# 6208           Misc  Nintendo      0.68      0.38      0.44         0.05
# 5650         Racing  Nintendo      0.21      0.14      0.38         0.04
# 1247   Role-Playing  Nintendo      0.58      0.06      0.37         0.04
# 1811         Action  Nintendo      0.47      0.26      0.35         0.07
# 15554  Role-Playing  Nintendo      0.46      0.31      0.33         0.08
# 255          Puzzle  Nintendo      0.26      0.00      0.31         0.02
# 9072   Role-Playing  Nintendo      0.71      0.19      0.31         0.03
# 12667  Role-Playing  Nintendo      0.80      0.38      0.30         0.13
# 16245          Misc  Nintendo      0.00      0.00      0.29         0.00
# 8349           Misc  Nintendo      0.00      0.00      0.27         0.01
# 1428           Misc  Nintendo      0.18      0.12      0.16         0.03
# 11713        Action  Nintendo      0.00      0.01      0.08         0.00
# 16585     Adventure  Nintendo      0.24      0.06      0.07         0.01
# 9527         Puzzle  Nintendo      0.36      0.08      0.00         0.01
#
#        Global_Sales
# 7829          31.38
# 9416          23.09
# 10555         18.35
# 10621         15.32
# 10917         15.84
# 1971          14.35
# 4806          11.90
# 1810          10.49
# 15678          8.34
# 4251          11.33
# 15894          4.96
# 2713           5.31
# 9650           5.45
# 14513          0.89
# 6986           2.05
# 6632           2.18
# 16325          3.63
# 5511           2.29
# 4087           1.32
# 7840           1.27
# 1925           1.58
# 6208           1.55
# 5650           0.77
# 1247           1.05
# 1811           1.15
# 15554          1.18
# 255            0.59
# 9072           1.24
# 12667          1.61
# 16245          0.29
# 8349           0.28
# 1428           0.49
# 11713          0.09
# 16585          0.38
# 9527           0.45

# %%
df.loc[df.Name.str.contains('Pokemon')].sort_values(by = 'Year', ascending = True) # 1996-2015년 출시
# Out:
#                                                     Name Platform  Year  \
# 7829                            Pokemon Red/Pokemon Blue       GB  1996
# 9650                                     Pokemon Stadium      N64  1999
# 9416                         Pokemon Gold/Pokemon Silver       GB  1999
# 2713                                     Pokemon Pinball       GB  1999
# 16325                                       Pokemon Snap      N64  1999
# 9527                               Pokemon Puzzle League      N64  2000
# 14513              Pokemon Card GB2: Here Comes Team GR!       GB  2001
# 10917                      Pokemon Ruby/Pokemon Sapphire      GBA  2002
# 16585                                    Pokemon Channel       GC  2003
# 8349                        Pokemon Box: Ruby & Sapphire       GC  2003
# 6208                    Pokemon Pinball: Ruby & Sapphire      GBA  2003
# 1810                   Pokemon FireRed/Pokemon LeafGreen      GBA  2004
# 5650                                        Pokemon Dash       DS  2004
# 9072                        Pokemon XD: Gale of Darkness       GC  2005
# 6986       Pokemon Mystery Dungeon: Red/Blue Rescue Team      GBA  2005
# 255                                      Pokemon Trozei!       DS  2005
# 10555                      Pokemon Diamond/Pokemon Pearl       DS  2006
# 6632                                      Pokemon Ranger       DS  2006
# 12667                          Pokemon Battle Revolution      Wii  2006
# 15894  Pokemon Mystery Dungeon: Explorers of Time/Exp...       DS  2007
# 5511                    Pokemon Ranger: Shadows of Almia       DS  2008
# 4806                Pokemon HeartGold/Pokemon SoulSilver       DS  2009
# 1925           Pokemon Mystery Dungeon: Explorers of Sky       DS  2009
# 4087                      Pokemon Ranger: Guardian Signs       DS  2010
# 10621                        Pokemon Black/Pokemon White       DS  2010
# 16245                    Battle & Get! Pokemon Typing DS       DS  2011
# 1811                                Pokemon Rumble Blast      3DS  2011
# 15678                    Pokemon Black 2/Pokemon White 2       DS  2012
# 7840          Pokemon Mystery Dungeon: Gates to Infinity      3DS  2012
# 1247                                    Pokemon Conquest       DS  2012
# 1971                                 Pokemon X/Pokemon Y      3DS  2013
# 4251           Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS  2014
# 1428                                 Pokemon Art Academy      3DS  2014
# 15554                      Pokemon Super Mystery Dungeon      3DS  2015
# 11713                               Pokemon Rumble World      3DS  2015
#
#               Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 7829   Role-Playing  Nintendo     11.27      8.89     10.22         1.00
# 9650       Strategy  Nintendo      3.18      1.24      0.94         0.09
# 9416   Role-Playing  Nintendo      9.00      6.18      7.20         0.71
# 2713           Misc  Nintendo      3.02      1.12      1.01         0.16
# 16325    Simulation  Nintendo      2.23      0.68      0.66         0.06
# 9527         Puzzle  Nintendo      0.36      0.08      0.00         0.01
# 14513      Strategy  Nintendo      0.00      0.00      0.89         0.00
# 10917  Role-Playing  Nintendo      6.06      3.90      5.38         0.50
# 16585     Adventure  Nintendo      0.24      0.06      0.07         0.01
# 8349           Misc  Nintendo      0.00      0.00      0.27         0.01
# 6208           Misc  Nintendo      0.68      0.38      0.44         0.05
# 1810   Role-Playing  Nintendo      4.34      2.65      3.15         0.35
# 5650         Racing  Nintendo      0.21      0.14      0.38         0.04
# 9072   Role-Playing  Nintendo      0.71      0.19      0.31         0.03
# 6986   Role-Playing  Nintendo      0.71      0.52      0.74         0.08
# 255          Puzzle  Nintendo      0.26      0.00      0.31         0.02
# 10555  Role-Playing  Nintendo      6.42      4.52      6.04         1.37
# 6632   Role-Playing  Nintendo      1.29      0.04      0.73         0.12
# 12667  Role-Playing  Nintendo      0.80      0.38      0.30         0.13
# 15894  Role-Playing  Nintendo      1.85      1.20      1.54         0.37
# 5511   Role-Playing  Nintendo      0.95      0.54      0.62         0.18
# 4806         Action  Nintendo      4.40      2.77      3.96         0.77
# 1925   Role-Playing  Nintendo      0.58      0.44      0.44         0.12
# 4087   Role-Playing  Nintendo      0.51      0.17      0.58         0.06
# 10621  Role-Playing  Nintendo      5.57      3.28      5.65         0.82
# 16245          Misc  Nintendo      0.00      0.00      0.29         0.00
# 1811         Action  Nintendo      0.47      0.26      0.35         0.07
# 15678  Role-Playing  Nintendo      2.91      1.86      3.14         0.43
# 7840   Role-Playing  Nintendo      0.44      0.30      0.47         0.06
# 1247   Role-Playing  Nintendo      0.58      0.06      0.37         0.04
# 1971   Role-Playing  Nintendo      5.17      4.05      4.34         0.79
# 4251   Role-Playing  Nintendo      4.23      3.37      3.08         0.65
# 1428           Misc  Nintendo      0.18      0.12      0.16         0.03
# 15554  Role-Playing  Nintendo      0.46      0.31      0.33         0.08
# 11713        Action  Nintendo      0.00      0.01      0.08         0.00
#
#        Global_Sales
# 7829          31.38
# 9650           5.45
# 9416          23.09
# 2713           5.31
# 16325          3.63
# 9527           0.45
# 14513          0.89
# 10917         15.84
# 16585          0.38
# 8349           0.28
# 6208           1.55
# 1810          10.49
# 5650           0.77
# 9072           1.24
# 6986           2.05
# 255            0.59
# 10555         18.35
# 6632           2.18
# 12667          1.61
# 15894          4.96
# 5511           2.29
# 4806          11.90
# 1925           1.58
# 4087           1.32
# 10621         15.32
# 16245          0.29
# 1811           1.15
# 15678          8.34
# 7840           1.27
# 1247           1.05
# 1971          14.35
# 4251          11.33
# 1428           0.49
# 15554          1.18
# 11713          0.09

# %%
df.loc[df.Name.str.contains('Pokemon')].JP_Sales.sum() / df.JP_Sales.sum() # 각 6400만 달러, 12억 9100만 달러 = 약 5%
# Out:
# 0.04991402147139472

# %%
df.sort_values(by = 'JP_Sales', ascending = False).head(20)
# Out:
#                                                  Name Platform  Year  \
# 7829                         Pokemon Red/Pokemon Blue       GB  1996
# 9416                      Pokemon Gold/Pokemon Silver       GB  1999
# 4199                                Super Mario Bros.      NES  1985
# 6937                            New Super Mario Bros.       DS  2006
# 10555                   Pokemon Diamond/Pokemon Pearl       DS  2006
# 10621                     Pokemon Black/Pokemon White       DS  2010
# 10917                   Pokemon Ruby/Pokemon Sapphire      GBA  2002
# 3273                      Animal Crossing: Wild World       DS  2005
# 511       Brain Age 2: More Training in Minutes a Day       DS  2005
# 1847                         Monster Hunter Freedom 3      PSP  2010
# 16531                       New Super Mario Bros. Wii      Wii  2009
# 8906                        Animal Crossing: New Leaf      3DS  2012
# 5218   Dragon Quest IX: Sentinels of the Starry Skies       DS  2009
# 1971                              Pokemon X/Pokemon Y      3DS  2013
# 1203                                           Tetris       GB  1989
# 9491                                 Super Mario Land       GB  1989
# 13229    Brain Age: Train Your Brain in Minutes a Day       DS  2005
# 4534                     Monster Hunter Freedom Unite      PSP  2008
# 10650                                   Mario Kart DS       DS  2005
# 163                Dragon Quest VII: Warriors of Eden       PS  2000
#
#               Genre         Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 7829   Role-Playing          Nintendo     11.27      8.89     10.22
# 9416   Role-Playing          Nintendo      9.00      6.18      7.20
# 4199       Platform          Nintendo     29.08      3.58      6.81
# 6937       Platform          Nintendo     11.38      9.23      6.50
# 10555  Role-Playing          Nintendo      6.42      4.52      6.04
# 10621  Role-Playing          Nintendo      5.57      3.28      5.65
# 10917  Role-Playing          Nintendo      6.06      3.90      5.38
# 3273     Simulation          Nintendo      2.55      3.52      5.33
# 511          Puzzle          Nintendo      3.44      5.36      5.32
# 1847   Role-Playing            Capcom      0.00      0.00      4.87
# 16531      Platform          Nintendo     14.59      7.06      4.70
# 8906     Simulation          Nintendo      2.01      2.32      4.36
# 5218   Role-Playing          Nintendo      0.66      0.69      4.35
# 1971   Role-Playing          Nintendo      5.17      4.05      4.34
# 1203         Puzzle          Nintendo     23.20      2.26      4.22
# 9491       Platform          Nintendo     10.83      2.71      4.18
# 13229          Misc          Nintendo      4.75      9.26      4.16
# 4534   Role-Playing            Capcom      0.47      0.57      4.13
# 10650        Racing          Nintendo      9.81      7.57      4.13
# 163    Role-Playing  Enix Corporation      0.20      0.14      4.10
#
#        Other_Sales  Global_Sales
# 7829          1.00         31.38
# 9416          0.71         23.09
# 4199          0.77         40.24
# 6937          2.90         30.01
# 10555         1.37         18.35
# 10621         0.82         15.32
# 10917         0.50         15.84
# 3273          0.88         12.28
# 511           1.18         15.30
# 1847          0.00          4.87
# 16531         2.26         28.61
# 8906          0.41          9.10
# 5218          0.15          5.85
# 1971          0.79         14.35
# 1203          0.58         30.26
# 9491          0.42         18.14
# 13229         2.05         20.22
# 4534          0.34          5.51
# 10650         1.92         23.43
# 163           0.02          4.46

# %%
df.loc[(df.Name.str.contains('Pokemon')) | (df.Name.str.contains('Mario')) | (df.Name.str.contains('Dragon'))].JP_Sales.sum()
# Out:
# 259.46999999999997

# %%
df.loc[(df.Name.str.contains('Pokemon')) | (df.Name.str.contains('Mario')) | (df.Name.str.contains('Dragon'))].JP_Sales.sum() / df.JP_Sales.sum() # 약 20.1% = 2억 5900만 / 12억 9100만 달러
# Out:
# 0.20098061997490357

# %%
df.loc[((df.Publisher == 'Nintendo')|(df.Publisher.str.contains('Sony')))].JP_Sales.sum() / df.JP_Sales.sum() # 약 41.3% = 5억 3200만 달러 / 12억 9100만 달러
# Out:
# 0.41247230871713847

# %%
df.loc[((df.Publisher == 'Nintendo') | (df.Publisher.str.contains('Namco')) | (df.Publisher.str.contains('Konami')) | (df.Publisher.str.contains('Sony')))].sort_values(by = 'JP_Sales', ascending = False)
# Out:
#                                          Name Platform  Year         Genre  \
# 7829                 Pokemon Red/Pokemon Blue       GB  1996  Role-Playing
# 9416              Pokemon Gold/Pokemon Silver       GB  1999  Role-Playing
# 4199                        Super Mario Bros.      NES  1985      Platform
# 6937                    New Super Mario Bros.       DS  2006      Platform
# 10555           Pokemon Diamond/Pokemon Pearl       DS  2006  Role-Playing
# ...                                       ...      ...   ...           ...
# 10486                Singstar: Ultimate Party      PS3  2014          Misc
# 10481                     Buzz! The Mega Quiz      PS2  2007          Misc
# 10467                        MLB 14: The Show      PSV  2014        Sports
# 2696   ESPN Winter X Games: Snowboarding 2002      PS2  2000        Sports
# 1                              The Munchables      Wii  2009        Action
#
#                                  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 7829                              Nintendo     11.27      8.89     10.22
# 9416                              Nintendo      9.00      6.18      7.20
# 4199                              Nintendo     29.08      3.58      6.81
# 6937                              Nintendo     11.38      9.23      6.50
# 10555                             Nintendo      6.42      4.52      6.04
# ...                                    ...       ...       ...       ...
# 10486   Sony Computer Entertainment Europe      0.00      0.12      0.00
# 10481          Sony Computer Entertainment      0.32      0.06      0.00
# 10467  Sony Computer Entertainment America      0.11      0.00      0.00
# 2696          Konami Digital Entertainment      0.10      0.08      0.00
# 1                       Namco Bandai Games      0.17      0.00      0.00
#
#        Other_Sales  Global_Sales
# 7829          1.00         31.38
# 9416          0.71         23.09
# 4199          0.77         40.24
# 6937          2.90         30.01
# 10555         1.37         18.35
# ...            ...           ...
# 10486         0.02          0.14
# 10481         0.50          0.88
# 10467         0.02          0.13
# 2696          0.03          0.21
# 1             0.01          0.18
#
# [3189 rows x 10 columns]
